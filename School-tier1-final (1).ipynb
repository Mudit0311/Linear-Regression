# %%
import pandas as pd
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
pd.set_option('display.max_colwidth',None)
import re
import ast
import numpy as np
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df = pd.read_excel ('Tier A.xlsx')

# %%
a=['countyId','zipcode', 'zestimate','lotAreaValue',
       'rentZestimate','bedrooms', 'bathrooms', 'livingAreaValue', 
       'lastSoldPrice', 'zestimateLowPercent', 'zestimateHighPercent',
       'restimateLowPercent', 'restimateHighPercent', 
       'taxAssessedValue', 'taxAssessedYear', 
       'propertyTaxRate',  
       'resoFacts_hasFireplace', 'resoFacts_parking',
       'mortgageRates_thirtyYearFixedRate',
       'mortgageRates_fifteenYearFixedRate', 'mortgageRates_arm5Rate', 
    'city', 'county' , 'description','parentRegion_name',
    'dateSoldString', 'resoFacts_daysOnZillow', 'resoFacts_flooring', 'resoFacts_hasAttachedProperty',
    'resoFacts_hasGarage', 'resoFacts_hasPetsAllowed', 'resoFacts_hasSpa' , 'resoFacts_hasView','resoFacts_hoaFee',
     'resoFacts_pricePerSquareFoot','resoFacts_yearBuilt' ,'solarPotential_sunScore','schools'
   ]

# %%
df=df[a]

# %%
df.shape
# Out:
# (742, 38)

# %%
df.isnull().sum().sum()
# Out:
# 2782

# %% [markdown]
# # Data Cleaning and Null Values removal

# %%
df['resoFacts_hoaFee'].fillna(df['resoFacts_hoaFee'].mode()[0], inplace=True)
hoe=[]
for x in df['resoFacts_hoaFee']:
    x=str(x).replace(",","")
    hoe.append(int(re.findall('[0-9,]+', x)[0]))
df['resoFacts_hoaFee']=hoe

# %%
df['resoFacts_flooring'].fillna(df['resoFacts_flooring'].mode()[0], inplace=True)
flooring=[]
for x in df['resoFacts_flooring']:
    x=x.replace('[',"")
    flooring.append(x.replace(']',""))
df['resoFacts_flooring']= flooring

# %%
df_cat= df.select_dtypes(exclude='number')
print(df_cat.shape)
# Out:
# (742, 6)

# %%
print(df_cat.isnull().sum())
# Out:
# city                  0
# county                0
# description           2
# parentRegion_name     2
# resoFacts_flooring    0
# schools               4
# dtype: int64

# %%
for column in df_cat:
    df_cat[column].fillna(df_cat[column].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
print(df_cat.isnull().sum().sum())
# Out:
# 0

# %%
discrete_cols= ["bedrooms", "bathrooms", "resoFacts_hasFireplace", "resoFacts_parking", "resoFacts_daysOnZillow" ,"resoFacts_hasAttachedProperty" , "resoFacts_hasGarage" , "resoFacts_hasPetsAllowed", "resoFacts_hasSpa", "resoFacts_hasView", "resoFacts_yearBuilt"]

# %%
numeric_cols=["lotAreaValue","zestimate","rentZestimate", "livingAreaValue", "lastSoldPrice", "zestimateLowPercent", "zestimateHighPercent", "restimateLowPercent" ,"restimateHighPercent" , "taxAssessedValue" , "propertyTaxRate", "resoFacts_hoaFee", "resoFacts_pricePerSquareFoot" , "solarPotential_sunScore"]

# %%
df_discrete=df[discrete_cols]
df_num=df[numeric_cols]

# %%
df_num.isnull().sum()
# Out:
# lotAreaValue                     58
# zestimate                       169
# rentZestimate                   122
# livingAreaValue                   9
# lastSoldPrice                   222
# zestimateLowPercent             169
# zestimateHighPercent            169
# restimateLowPercent             177
# restimateHighPercent            177
# taxAssessedValue                134
# propertyTaxRate                   2
# resoFacts_hoaFee                  0
# resoFacts_pricePerSquareFoot     37
# solarPotential_sunScore         146
# dtype: int64

# %%
from sklearn.impute import KNNImputer   # missing values imputation

imputer = KNNImputer(n_neighbors=2)  #impute missing values
df_num.iloc[:,0:]=imputer.fit_transform(df_num.iloc[:,0:]) #replace df with imputed missing values
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
df_num.isnull().sum().sum()
# Out:
# 0

# %%
df_discrete.isnull().sum()
# Out:
# bedrooms                          22
# bathrooms                          8
# resoFacts_hasFireplace           117
# resoFacts_parking                  0
# resoFacts_daysOnZillow             1
# resoFacts_hasAttachedProperty      0
# resoFacts_hasGarage                0
# resoFacts_hasPetsAllowed           0
# resoFacts_hasSpa                   0
# resoFacts_hasView                  0
# resoFacts_yearBuilt               10
# dtype: int64

# %%
#df_discret= df_discrete.dropna()

# %%
df_discrete.resoFacts_hasFireplace.value_counts()
# Out:
# 1.00000    385
# 0.00000    240
# Name: resoFacts_hasFireplace, dtype: int64

# %%
df_discrete['resoFacts_hasFireplace'].fillna(0, inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df_discrete.isnull().sum()
# Out:
# bedrooms                         22
# bathrooms                         8
# resoFacts_hasFireplace            0
# resoFacts_parking                 0
# resoFacts_daysOnZillow            1
# resoFacts_hasAttachedProperty     0
# resoFacts_hasGarage               0
# resoFacts_hasPetsAllowed          0
# resoFacts_hasSpa                  0
# resoFacts_hasView                 0
# resoFacts_yearBuilt              10
# dtype: int64

# %%
for column in df_discrete:
    df_discrete[column].fillna(df_discrete[column].mode()[0], inplace=True)

# %%
df_discrete.isnull().sum()
# Out:
# bedrooms                         0
# bathrooms                        0
# resoFacts_hasFireplace           0
# resoFacts_parking                0
# resoFacts_daysOnZillow           0
# resoFacts_hasAttachedProperty    0
# resoFacts_hasGarage              0
# resoFacts_hasPetsAllowed         0
# resoFacts_hasSpa                 0
# resoFacts_hasView                0
# resoFacts_yearBuilt              0
# dtype: int64

# %%
print(df_cat.shape)
print(df_num.shape)
print(df_discrete.shape)
# Out:
# (742, 6)
# (742, 14)
# (742, 11)

# %%
df_discrete['resoFacts_parking']=np.where(df_discrete['resoFacts_parking']>=1,1,0)
# Out:
# <ipython-input-116-4ece1c62a106>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_discrete['resoFacts_parking']=np.where(df_discrete['resoFacts_parking']>=1,1,0)

# %%
df_discrete.resoFacts_parking.value_counts()
# Out:
# 1    512
# 0    230
# Name: resoFacts_parking, dtype: int64

# %%
df= pd.concat([df_cat,df_num,df_discrete], axis=1)  # this df is without null values

# %%
df.shape
# Out:
# (742, 31)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Feature Engineering- Creating 6 features out of school

# %%
#df_2= pd.read_excel('zillow_full.xlsx')

# %%
schools= list(df['schools'])

# %%
list_schools= [[]] * len(schools)

# %%
len(list_schools)
# Out:
# 742

# %%
i=0
for x in schools:
    list_schools[i]=[0,0,0,0,0,0]
    x = str(x).replace('\\','"')
    l=re.findall("[{][\\a-zA-z0-9:',\-/ \.=?&]+[}]", x)
    for y in l:
        y=ast.literal_eval(y)
        if y['level']== 'Elementary':
            if y['rating']!=None:
                if list_schools[i][1]<y['rating']:
                    list_schools[i][1]=y['rating']
                    list_schools[i][0]=y['distance']
                
        if y['level']== 'Middle':
            if y['rating']!=None:
                if list_schools[i][3]<y['rating']:
                    list_schools[i][3]=y['rating']
                    list_schools[i][2]=y['distance']
        if y['level']=='High':
            if y['rating']!=None:
                if list_schools[i][5]<y['rating']:
                    list_schools[i][5]=y['rating']
                    list_schools[i][4]=y['distance']
    
    i+=1

# %%
list_schools[0]
# Out:
# [0.4, 8, 1.4, 6, 1.3, 7]

# %%
for i in range(len(list_schools)):
    list_schools[i] = [None if item <=0 else item for item in list_schools[i]]

# %%
df_3 = pd.DataFrame(list_schools, columns = ['Elementary_Distance', 'Elementary_Ratings', 'Middle_Distance', 'Middle_Ratings', 'High_Distance', 'High_Ratings'])

# %%
df_3['Elementary_Distance']=np.where(np.isnan(df_3['Elementary_Distance']),df_3['Elementary_Distance'].median(),df_3['Elementary_Distance']) 
df_3['Middle_Ratings']=np.where(np.isnan(df_3['Middle_Ratings']),df_3['Middle_Ratings'].mode(),df_3['Middle_Ratings']) 
df_3['Middle_Distance']=np.where(np.isnan(df_3['Middle_Distance']),df_3['Middle_Distance'].median(),df_3['Middle_Distance']) 
df_3['High_Ratings']=np.where(np.isnan(df_3['High_Ratings']),df_3['High_Ratings'].mode(),df_3['High_Ratings']) 
df_3['High_Distance']=np.where(np.isnan(df_3['High_Distance']),df_3['High_Distance'].median(),df_3['High_Distance'])

# %%
imputer = KNNImputer(n_neighbors=2)  #impute missing values
df_3.iloc[:,0:]=imputer.fit_transform(df_3.iloc[:,0:]) #replace df with imputed missing values

# %%
df_3.shape
# Out:
# (742, 6)

# %%
df_3.isnull().sum()
# Out:
# Elementary_Distance    0
# Elementary_Ratings     0
# Middle_Distance        0
# Middle_Ratings         0
# High_Distance          0
# High_Ratings           0
# dtype: int64

# %%
df.shape
# Out:
# (742, 31)

# %%
df.drop('schools', axis=1, inplace= True)

# %%
df.shape
# Out:
# (742, 30)

# %%
df=df.reset_index()

# %%
df=pd.concat([df,df_3], axis=1)

# %%
df.shape  # this df contains school columns also
# Out:
# (742, 37)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Outliers

# %%
#columns_for_outliers=[ 'bedrooms','lastSoldPrice','Elementary_Ratings','Elementary_Distance',
 #      'Middle_Ratings','Middle_Distance', 'High_Distance', 'High_Ratings','livingAreaValue','resoFacts_hasGarage']

# %%
columns_for_outliers= ['Elementary_Ratings','Elementary_Distance',
    'Middle_Ratings','Middle_Distance', 'High_Distance', 'High_Ratings']

# %%
# Detecting outliers and imputing nan 
from scipy.stats import skew

for x in columns_for_outliers:
        percentile25 = df[x].quantile(0.25)
        percentile75 = df[x].quantile(0.75)
        iqr= percentile75-percentile25
        upper = percentile75 + 1.5 * iqr
        lower = percentile25 - 1.5 * iqr
        for y in df[x]:
            if (y>upper) or (y<lower):
                df[x].loc[df[x] == y]=None
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df.isnull().sum()
# Out:
# index                             0
# city                              0
# county                            0
# description                       0
# parentRegion_name                 0
# resoFacts_flooring                0
# lotAreaValue                      0
# zestimate                         0
# rentZestimate                     0
# livingAreaValue                   0
# lastSoldPrice                     0
# zestimateLowPercent               0
# zestimateHighPercent              0
# restimateLowPercent               0
# restimateHighPercent              0
# taxAssessedValue                  0
# propertyTaxRate                   0
# resoFacts_hoaFee                  0
# resoFacts_pricePerSquareFoot      0
# solarPotential_sunScore           0
# bedrooms                          0
# bathrooms                         0
# resoFacts_hasFireplace            0
# resoFacts_parking                 0
# resoFacts_daysOnZillow            0
# resoFacts_hasAttachedProperty     0
# resoFacts_hasGarage               0
# resoFacts_hasPetsAllowed          0
# resoFacts_hasSpa                  0
# resoFacts_hasView                 0
# resoFacts_yearBuilt               0
# Elementary_Distance              53
# Elementary_Ratings                0
# Middle_Distance                  26
# Middle_Ratings                    0
# High_Distance                    33
# High_Ratings                     66
# dtype: int64

# %%
df= df.dropna()

# %%
df.shape
# Out:
# (615, 37)

# %% [markdown]
# # Feature Engineering- Creating New feature out of feature("description")

# %%
sentiment_des = []
from textblob import TextBlob
for text in df['description'].values:
        t= TextBlob(text)
        sentiment_des.append(t.sentiment[0])
df['desc_sentiment']=sentiment_des

# %%
df['desc_sentiment']=sentiment_des

# %%
df.drop(['description'], axis=1,inplace=True)

# %%
df.shape
# Out:
# (615, 37)

# %%
df.corr()
# Out:
#                                  index  lotAreaValue  zestimate  \
# index                          1.00000       0.21948    0.01264
# lotAreaValue                   0.21948       1.00000    0.05799
# zestimate                      0.01264       0.05799    1.00000
# rentZestimate                 -0.08345      -0.06329    0.84205
# livingAreaValue               -0.00506       0.01414    0.54567
# lastSoldPrice                 -0.24461      -0.00319    0.47359
# zestimateLowPercent           -0.33418      -0.09365    0.10555
# zestimateHighPercent          -0.31079      -0.11211    0.08796
# restimateLowPercent           -0.05339      -0.10863    0.34424
# restimateHighPercent          -0.05535      -0.06112    0.24225
# taxAssessedValue              -0.03201      -0.10545    0.10323
# propertyTaxRate                0.33380       0.25312   -0.19619
# resoFacts_hoaFee              -0.10221      -0.12822    0.20678
# resoFacts_pricePerSquareFoot   0.05813       0.01951   -0.00731
# solarPotential_sunScore        0.04461       0.08667   -0.01669
# bedrooms                       0.11524       0.21722    0.45614
# bathrooms                      0.05915       0.04403    0.41658
# resoFacts_hasFireplace         0.14161       0.30488    0.14511
# resoFacts_parking             -0.13439      -0.00683    0.07090
# resoFacts_daysOnZillow         0.20531       0.04097    0.08228
# resoFacts_hasAttachedProperty -0.25050      -0.22145   -0.03403
# resoFacts_hasGarage           -0.12101      -0.00268    0.08084
# resoFacts_hasPetsAllowed      -0.13712      -0.14460   -0.04387
# resoFacts_hasSpa               0.05029       0.00089   -0.06930
# resoFacts_hasView             -0.08867      -0.09359    0.19517
# resoFacts_yearBuilt            0.10775       0.11111    0.00458
# Elementary_Distance            0.03985      -0.07598   -0.07354
# Elementary_Ratings             0.01854       0.10856    0.14662
# Middle_Distance               -0.00945      -0.08738   -0.08457
# Middle_Ratings                 0.11634       0.10692    0.16491
# High_Distance                  0.20705      -0.02418   -0.08276
# High_Ratings                   0.18765       0.11773    0.04144
# desc_sentiment                -0.00337       0.01472    0.07709
#
#                                rentZestimate  livingAreaValue  lastSoldPrice  \
# index                               -0.08345         -0.00506       -0.24461
# lotAreaValue                        -0.06329          0.01414       -0.00319
# zestimate                            0.84205          0.54567        0.47359
# rentZestimate                        1.00000          0.44384        0.41226
# livingAreaValue                      0.44384          1.00000        0.50960
# lastSoldPrice                        0.41226          0.50960        1.00000
# zestimateLowPercent                  0.08923          0.19865        0.23650
# zestimateHighPercent                 0.08806          0.21308        0.27422
# restimateLowPercent                  0.41488          0.20164        0.22236
# restimateHighPercent                 0.22331          0.19680        0.17105
# taxAssessedValue                     0.12024          0.10683        0.18584
# propertyTaxRate                     -0.30243         -0.07024       -0.21329
# resoFacts_hoaFee                     0.14547         -0.03562        0.06158
# resoFacts_pricePerSquareFoot        -0.03702         -0.06263       -0.00086
# solarPotential_sunScore             -0.02874         -0.09618       -0.02642
# bedrooms                             0.37020          0.59065        0.22438
# bathrooms                            0.39325          0.51550        0.29900
# resoFacts_hasFireplace               0.07307          0.08141       -0.03734
# resoFacts_parking                    0.13213          0.08867        0.04699
# resoFacts_daysOnZillow              -0.00261          0.06099       -0.04513
# resoFacts_hasAttachedProperty        0.06070         -0.20509       -0.00813
# resoFacts_hasGarage                  0.13081          0.13158        0.09095
# resoFacts_hasPetsAllowed            -0.02821         -0.09999        0.05784
# resoFacts_hasSpa                    -0.03721          0.00485       -0.05640
# resoFacts_hasView                    0.20703          0.14320        0.15928
# resoFacts_yearBuilt                 -0.06079         -0.00092       -0.04788
# Elementary_Distance                 -0.03132          0.03811       -0.03947
# Elementary_Ratings                   0.09630          0.08179        0.06332
# Middle_Distance                     -0.09423         -0.04624        0.00027
# Middle_Ratings                       0.08041          0.17356        0.05283
# High_Distance                       -0.15074          0.01520       -0.05383
# High_Ratings                        -0.03252          0.07921       -0.09357
# desc_sentiment                       0.09124          0.05430        0.04580
#
#                                zestimateLowPercent  zestimateHighPercent  \
# index                                     -0.33418              -0.31079
# lotAreaValue                              -0.09365              -0.11211
# zestimate                                  0.10555               0.08796
# rentZestimate                              0.08923               0.08806
# livingAreaValue                            0.19865               0.21308
# lastSoldPrice                              0.23650               0.27422
# zestimateLowPercent                        1.00000               0.90867
# zestimateHighPercent                       0.90867               1.00000
# restimateLowPercent                        0.16484               0.14569
# restimateHighPercent                       0.22067               0.24232
# taxAssessedValue                           0.00836               0.06172
# propertyTaxRate                           -0.24493              -0.22420
# resoFacts_hoaFee                          -0.05321              -0.05081
# resoFacts_pricePerSquareFoot               0.03735               0.03058
# solarPotential_sunScore                   -0.05485              -0.03891
# bedrooms                                   0.05806               0.03033
# bathrooms                                 -0.08072              -0.08970
# resoFacts_hasFireplace                    -0.13462              -0.16226
# resoFacts_parking                         -0.01173              -0.02613
# resoFacts_daysOnZillow                    -0.07895              -0.04060
# resoFacts_hasAttachedProperty              0.07243               0.03266
# resoFacts_hasGarage                        0.04408               0.01976
# resoFacts_hasPetsAllowed                  -0.05725              -0.03833
# resoFacts_hasSpa                          -0.08469              -0.06824
# resoFacts_hasView                         -0.04807              -0.01321
# resoFacts_yearBuilt                       -0.10690              -0.10388
# Elementary_Distance                       -0.10198              -0.06301
# Elementary_Ratings                        -0.05525              -0.10241
# Middle_Distance                           -0.07435              -0.04340
# Middle_Ratings                             0.00607              -0.04848
# High_Distance                             -0.19317              -0.14918
# High_Ratings                              -0.16994              -0.20094
# desc_sentiment                             0.03111              -0.02426
#
#                                restimateLowPercent  restimateHighPercent  \
# index                                     -0.05339              -0.05535
# lotAreaValue                              -0.10863              -0.06112
# zestimate                                  0.34424               0.24225
# rentZestimate                              0.41488               0.22331
# livingAreaValue                            0.20164               0.19680
# lastSoldPrice                              0.22236               0.17105
# zestimateLowPercent                        0.16484               0.22067
# zestimateHighPercent                       0.14569               0.24232
# restimateLowPercent                        1.00000               0.66853
# restimateHighPercent                       0.66853               1.00000
# taxAssessedValue                           0.12514              -0.00101
# propertyTaxRate                           -0.26150              -0.25060
# resoFacts_hoaFee                           0.05536               0.14013
# resoFacts_pricePerSquareFoot              -0.04546              -0.02269
# solarPotential_sunScore                   -0.02399              -0.05704
# bedrooms                                   0.15137               0.04320
# bathrooms                                  0.11607              -0.01648
# resoFacts_hasFireplace                    -0.01559              -0.11208
# resoFacts_parking                          0.06042               0.03428
# resoFacts_daysOnZillow                    -0.07737              -0.06064
# resoFacts_hasAttachedProperty              0.12479               0.07661
# resoFacts_hasGarage                        0.06165               0.01202
# resoFacts_hasPetsAllowed                   0.02561               0.05481
# resoFacts_hasSpa                          -0.05972              -0.05329
# resoFacts_hasView                          0.09065               0.06497
# resoFacts_yearBuilt                       -0.06276              -0.08331
# Elementary_Distance                       -0.01390              -0.01428
# Elementary_Ratings                        -0.01847              -0.09713
# Middle_Distance                           -0.13244              -0.12511
# Middle_Ratings                            -0.04265              -0.03584
# High_Distance                             -0.13473              -0.11994
# High_Ratings                              -0.06618              -0.11260
# desc_sentiment                             0.04388               0.04893
#
#                                taxAssessedValue  propertyTaxRate  \
# index                                  -0.03201          0.33380
# lotAreaValue                           -0.10545          0.25312
# zestimate                               0.10323         -0.19619
# rentZestimate                           0.12024         -0.30243
# livingAreaValue                         0.10683         -0.07024
# lastSoldPrice                           0.18584         -0.21329
# zestimateLowPercent                     0.00836         -0.24493
# zestimateHighPercent                    0.06172         -0.22420
# restimateLowPercent                     0.12514         -0.26150
# restimateHighPercent                   -0.00101         -0.25060
# taxAssessedValue                        1.00000         -0.04267
# propertyTaxRate                        -0.04267          1.00000
# resoFacts_hoaFee                        0.03229         -0.43579
# resoFacts_pricePerSquareFoot           -0.00613          0.03498
# solarPotential_sunScore                 0.01061         -0.02071
# bedrooms                                0.05456          0.13373
# bathrooms                               0.13257          0.07782
# resoFacts_hasFireplace                 -0.08375          0.22075
# resoFacts_parking                      -0.01664         -0.11724
# resoFacts_daysOnZillow                 -0.00312          0.25941
# resoFacts_hasAttachedProperty          -0.00527         -0.47434
# resoFacts_hasGarage                    -0.06511         -0.09799
# resoFacts_hasPetsAllowed                0.03929         -0.23166
# resoFacts_hasSpa                        0.01582          0.02417
# resoFacts_hasView                       0.07137         -0.18509
# resoFacts_yearBuilt                    -0.11517          0.13208
# Elementary_Distance                     0.06804          0.16188
# Elementary_Ratings                     -0.04104          0.12216
# Middle_Distance                        -0.02409          0.09860
# Middle_Ratings                         -0.03899          0.17344
# High_Distance                          -0.00073          0.35706
# High_Ratings                           -0.02846          0.26099
# desc_sentiment                         -0.01035         -0.07061
#
#                                resoFacts_hoaFee  resoFacts_pricePerSquareFoot  \
# index                                  -0.10221                       0.05813
# lotAreaValue                           -0.12822                       0.01951
# zestimate                               0.20678                      -0.00731
# rentZestimate                           0.14547                      -0.03702
# livingAreaValue                        -0.03562                      -0.06263
# lastSoldPrice                           0.06158                      -0.00086
# zestimateLowPercent                    -0.05321                       0.03735
# zestimateHighPercent                   -0.05081                       0.03058
# restimateLowPercent                     0.05536                      -0.04546
# restimateHighPercent                    0.14013                      -0.02269
# taxAssessedValue                        0.03229                      -0.00613
# propertyTaxRate                        -0.43579                       0.03498
# resoFacts_hoaFee                        1.00000                      -0.00583
# resoFacts_pricePerSquareFoot           -0.00583                       1.00000
# solarPotential_sunScore                 0.09784                       0.01468
# bedrooms                               -0.21964                      -0.03638
# bathrooms                              -0.05178                      -0.04606
# resoFacts_hasFireplace                 -0.06352                      -0.04538
# resoFacts_parking                       0.09692                       0.02669
# resoFacts_daysOnZillow                 -0.07324                       0.56702
# resoFacts_hasAttachedProperty           0.29481                      -0.02012
# resoFacts_hasGarage                     0.00710                       0.03517
# resoFacts_hasPetsAllowed                0.33740                      -0.01574
# resoFacts_hasSpa                        0.00883                      -0.01227
# resoFacts_hasView                       0.15105                      -0.02303
# resoFacts_yearBuilt                    -0.03959                       0.00610
# Elementary_Distance                    -0.05584                      -0.01933
# Elementary_Ratings                      0.01127                       0.01788
# Middle_Distance                        -0.00796                      -0.03955
# Middle_Ratings                         -0.03971                       0.02098
# High_Distance                          -0.11334                      -0.03023
# High_Ratings                            0.02146                       0.02164
# desc_sentiment                          0.07792                      -0.07571
#
#                                solarPotential_sunScore  bedrooms  bathrooms  \
# index                                          0.04461   0.11524    0.05915
# lotAreaValue                                   0.08667   0.21722    0.04403
# zestimate                                     -0.01669   0.45614    0.41658
# rentZestimate                                 -0.02874   0.37020    0.39325
# livingAreaValue                               -0.09618   0.59065    0.51550
# lastSoldPrice                                 -0.02642   0.22438    0.29900
# zestimateLowPercent                           -0.05485   0.05806   -0.08072
# zestimateHighPercent                          -0.03891   0.03033   -0.08970
# restimateLowPercent                           -0.02399   0.15137    0.11607
# restimateHighPercent                          -0.05704   0.04320   -0.01648
# taxAssessedValue                               0.01061   0.05456    0.13257
# propertyTaxRate                               -0.02071   0.13373    0.07782
# resoFacts_hoaFee                               0.09784  -0.21964   -0.05178
# resoFacts_pricePerSquareFoot                   0.01468  -0.03638   -0.04606
# solarPotential_sunScore                        1.00000  -0.05650   -0.03931
# bedrooms                                      -0.05650   1.00000    0.64145
# bathrooms                                     -0.03931   0.64145    1.00000
# resoFacts_hasFireplace                        -0.03766   0.23330    0.19979
# resoFacts_parking                             -0.04113   0.09659    0.15709
# resoFacts_daysOnZillow                        -0.01577   0.07918    0.05868
# resoFacts_hasAttachedProperty                 -0.00311  -0.29262   -0.14406
# resoFacts_hasGarage                           -0.10576   0.13601    0.17637
# resoFacts_hasPetsAllowed                       0.08780  -0.25716   -0.03441
# resoFacts_hasSpa                               0.01077   0.02152    0.05123
# resoFacts_hasView                             -0.04230   0.06447    0.18303
# resoFacts_yearBuilt                            0.00439   0.05656    0.05605
# Elementary_Distance                           -0.05618  -0.05334    0.07486
# Elementary_Ratings                             0.05036   0.16433    0.13974
# Middle_Distance                                0.02448  -0.07370    0.02971
# Middle_Ratings                                 0.00737   0.17996    0.14633
# High_Distance                                 -0.01851   0.02816    0.10418
# High_Ratings                                   0.06467   0.13246    0.14509
# desc_sentiment                                 0.03324   0.04823    0.03883
#
#                                resoFacts_hasFireplace  resoFacts_parking  \
# index                                         0.14161           -0.13439
# lotAreaValue                                  0.30488           -0.00683
# zestimate                                     0.14511            0.07090
# rentZestimate                                 0.07307            0.13213
# livingAreaValue                               0.08141            0.08867
# lastSoldPrice                                -0.03734            0.04699
# zestimateLowPercent                          -0.13462           -0.01173
# zestimateHighPercent                         -0.16226           -0.02613
# restimateLowPercent                          -0.01559            0.06042
# restimateHighPercent                         -0.11208            0.03428
# taxAssessedValue                             -0.08375           -0.01664
# propertyTaxRate                               0.22075           -0.11724
# resoFacts_hoaFee                             -0.06352            0.09692
# resoFacts_pricePerSquareFoot                 -0.04538            0.02669
# solarPotential_sunScore                      -0.03766           -0.04113
# bedrooms                                      0.23330            0.09659
# bathrooms                                     0.19979            0.15709
# resoFacts_hasFireplace                        1.00000            0.06997
# resoFacts_parking                             0.06997            1.00000
# resoFacts_daysOnZillow                       -0.01011           -0.07503
# resoFacts_hasAttachedProperty                -0.13703            0.21319
# resoFacts_hasGarage                           0.06767            0.74645
# resoFacts_hasPetsAllowed                     -0.12503            0.20420
# resoFacts_hasSpa                              0.06759           -0.06739
# resoFacts_hasView                             0.03490            0.16122
# resoFacts_yearBuilt                           0.16564            0.13879
# Elementary_Distance                           0.01726            0.01699
# Elementary_Ratings                            0.16088            0.11055
# Middle_Distance                              -0.06256            0.00235
# Middle_Ratings                                0.16446            0.10575
# High_Distance                                 0.00099           -0.17693
# High_Ratings                                  0.14487            0.02774
# desc_sentiment                                0.12055            0.08852
#
#                                resoFacts_daysOnZillow  \
# index                                         0.20531
# lotAreaValue                                  0.04097
# zestimate                                     0.08228
# rentZestimate                                -0.00261
# livingAreaValue                               0.06099
# lastSoldPrice                                -0.04513
# zestimateLowPercent                          -0.07895
# zestimateHighPercent                         -0.04060
# restimateLowPercent                          -0.07737
# restimateHighPercent                         -0.06064
# taxAssessedValue                             -0.00312
# propertyTaxRate                               0.25941
# resoFacts_hoaFee                             -0.07324
# resoFacts_pricePerSquareFoot                  0.56702
# solarPotential_sunScore                      -0.01577
# bedrooms                                      0.07918
# bathrooms                                     0.05868
# resoFacts_hasFireplace                       -0.01011
# resoFacts_parking                            -0.07503
# resoFacts_daysOnZillow                        1.00000
# resoFacts_hasAttachedProperty                -0.16975
# resoFacts_hasGarage                          -0.04286
# resoFacts_hasPetsAllowed                     -0.07815
# resoFacts_hasSpa                             -0.00174
# resoFacts_hasView                            -0.05775
# resoFacts_yearBuilt                           0.01499
# Elementary_Distance                           0.12717
# Elementary_Ratings                            0.06265
# Middle_Distance                               0.02866
# Middle_Ratings                                0.09656
# High_Distance                                 0.10846
# High_Ratings                                  0.13835
# desc_sentiment                               -0.09224
#
#                                resoFacts_hasAttachedProperty  \
# index                                               -0.25050
# lotAreaValue                                        -0.22145
# zestimate                                           -0.03403
# rentZestimate                                        0.06070
# livingAreaValue                                     -0.20509
# lastSoldPrice                                       -0.00813
# zestimateLowPercent                                  0.07243
# zestimateHighPercent                                 0.03266
# restimateLowPercent                                  0.12479
# restimateHighPercent                                 0.07661
# taxAssessedValue                                    -0.00527
# propertyTaxRate                                     -0.47434
# resoFacts_hoaFee                                     0.29481
# resoFacts_pricePerSquareFoot                        -0.02012
# solarPotential_sunScore                             -0.00311
# bedrooms                                            -0.29262
# bathrooms                                           -0.14406
# resoFacts_hasFireplace                              -0.13703
# resoFacts_parking                                    0.21319
# resoFacts_daysOnZillow                              -0.16975
# resoFacts_hasAttachedProperty                        1.00000
# resoFacts_hasGarage                                  0.12948
# resoFacts_hasPetsAllowed                             0.30185
# resoFacts_hasSpa                                    -0.04538
# resoFacts_hasView                                    0.17951
# resoFacts_yearBuilt                                 -0.08246
# Elementary_Distance                                 -0.03922
# Elementary_Ratings                                  -0.10838
# Middle_Distance                                      0.00511
# Middle_Ratings                                      -0.08298
# High_Distance                                       -0.24253
# High_Ratings                                        -0.17404
# desc_sentiment                                       0.13217
#
#                                resoFacts_hasGarage  resoFacts_hasPetsAllowed  \
# index                                     -0.12101                  -0.13712
# lotAreaValue                              -0.00268                  -0.14460
# zestimate                                  0.08084                  -0.04387
# rentZestimate                              0.13081                  -0.02821
# livingAreaValue                            0.13158                  -0.09999
# lastSoldPrice                              0.09095                   0.05784
# zestimateLowPercent                        0.04408                  -0.05725
# zestimateHighPercent                       0.01976                  -0.03833
# restimateLowPercent                        0.06165                   0.02561
# restimateHighPercent                       0.01202                   0.05481
# taxAssessedValue                          -0.06511                   0.03929
# propertyTaxRate                           -0.09799                  -0.23166
# resoFacts_hoaFee                           0.00710                   0.33740
# resoFacts_pricePerSquareFoot               0.03517                  -0.01574
# solarPotential_sunScore                   -0.10576                   0.08780
# bedrooms                                   0.13601                  -0.25716
# bathrooms                                  0.17637                  -0.03441
# resoFacts_hasFireplace                     0.06767                  -0.12503
# resoFacts_parking                          0.74645                   0.20420
# resoFacts_daysOnZillow                    -0.04286                  -0.07815
# resoFacts_hasAttachedProperty              0.12948                   0.30185
# resoFacts_hasGarage                        1.00000                   0.20582
# resoFacts_hasPetsAllowed                   0.20582                   1.00000
# resoFacts_hasSpa                          -0.05488                  -0.06139
# resoFacts_hasView                          0.18592                   0.14064
# resoFacts_yearBuilt                        0.12912                  -0.03751
# Elementary_Distance                        0.01453                   0.00607
# Elementary_Ratings                         0.10013                   0.05893
# Middle_Distance                            0.00939                   0.15027
# Middle_Ratings                             0.11440                  -0.02752
# High_Distance                             -0.12492                  -0.02096
# High_Ratings                               0.03842                  -0.07964
# desc_sentiment                             0.07182                  -0.02168
#
#                                resoFacts_hasSpa  resoFacts_hasView  \
# index                                   0.05029           -0.08867
# lotAreaValue                            0.00089           -0.09359
# zestimate                              -0.06930            0.19517
# rentZestimate                          -0.03721            0.20703
# livingAreaValue                         0.00485            0.14320
# lastSoldPrice                          -0.05640            0.15928
# zestimateLowPercent                    -0.08469           -0.04807
# zestimateHighPercent                   -0.06824           -0.01321
# restimateLowPercent                    -0.05972            0.09065
# restimateHighPercent                   -0.05329            0.06497
# taxAssessedValue                        0.01582            0.07137
# propertyTaxRate                         0.02417           -0.18509
# resoFacts_hoaFee                        0.00883            0.15105
# resoFacts_pricePerSquareFoot           -0.01227           -0.02303
# solarPotential_sunScore                 0.01077           -0.04230
# bedrooms                                0.02152            0.06447
# bathrooms                               0.05123            0.18303
# resoFacts_hasFireplace                  0.06759            0.03490
# resoFacts_parking                      -0.06739            0.16122
# resoFacts_daysOnZillow                 -0.00174           -0.05775
# resoFacts_hasAttachedProperty          -0.04538            0.17951
# resoFacts_hasGarage                    -0.05488            0.18592
# resoFacts_hasPetsAllowed               -0.06139            0.14064
# resoFacts_hasSpa                        1.00000            0.00691
# resoFacts_hasView                       0.00691            1.00000
# resoFacts_yearBuilt                     0.07550           -0.04452
# Elementary_Distance                     0.09046            0.01296
# Elementary_Ratings                     -0.01466            0.00518
# Middle_Distance                        -0.00278           -0.06491
# Middle_Ratings                         -0.06931           -0.06941
# High_Distance                           0.11408           -0.02284
# High_Ratings                            0.02621            0.03736
# desc_sentiment                         -0.02742            0.08641
#
#                                resoFacts_yearBuilt  Elementary_Distance  \
# index                                      0.10775              0.03985
# lotAreaValue                               0.11111             -0.07598
# zestimate                                  0.00458             -0.07354
# rentZestimate                             -0.06079             -0.03132
# livingAreaValue                           -0.00092              0.03811
# lastSoldPrice                             -0.04788             -0.03947
# zestimateLowPercent                       -0.10690             -0.10198
# zestimateHighPercent                      -0.10388             -0.06301
# restimateLowPercent                       -0.06276             -0.01390
# restimateHighPercent                      -0.08331             -0.01428
# taxAssessedValue                          -0.11517              0.06804
# propertyTaxRate                            0.13208              0.16188
# resoFacts_hoaFee                          -0.03959             -0.05584
# resoFacts_pricePerSquareFoot               0.00610             -0.01933
# solarPotential_sunScore                    0.00439             -0.05618
# bedrooms                                   0.05656             -0.05334
# bathrooms                                  0.05605              0.07486
# resoFacts_hasFireplace                     0.16564              0.01726
# resoFacts_parking                          0.13879              0.01699
# resoFacts_daysOnZillow                     0.01499              0.12717
# resoFacts_hasAttachedProperty             -0.08246             -0.03922
# resoFacts_hasGarage                        0.12912              0.01453
# resoFacts_hasPetsAllowed                  -0.03751              0.00607
# resoFacts_hasSpa                           0.07550              0.09046
# resoFacts_hasView                         -0.04452              0.01296
# resoFacts_yearBuilt                        1.00000             -0.03453
# Elementary_Distance                       -0.03453              1.00000
# Elementary_Ratings                         0.07690              0.01991
# Middle_Distance                            0.04677              0.07120
# Middle_Ratings                            -0.00415             -0.09329
# High_Distance                              0.03807              0.17284
# High_Ratings                               0.01928              0.00432
# desc_sentiment                             0.01743             -0.05997
#
#                                Elementary_Ratings  Middle_Distance  \
# index                                     0.01854         -0.00945
# lotAreaValue                              0.10856         -0.08738
# zestimate                                 0.14662         -0.08457
# rentZestimate                             0.09630         -0.09423
# livingAreaValue                           0.08179         -0.04624
# lastSoldPrice                             0.06332          0.00027
# zestimateLowPercent                      -0.05525         -0.07435
# zestimateHighPercent                     -0.10241         -0.04340
# restimateLowPercent                      -0.01847         -0.13244
# restimateHighPercent                     -0.09713         -0.12511
# taxAssessedValue                         -0.04104         -0.02409
# propertyTaxRate                           0.12216          0.09860
# resoFacts_hoaFee                          0.01127         -0.00796
# resoFacts_pricePerSquareFoot              0.01788         -0.03955
# solarPotential_sunScore                   0.05036          0.02448
# bedrooms                                  0.16433         -0.07370
# bathrooms                                 0.13974          0.02971
# resoFacts_hasFireplace                    0.16088         -0.06256
# resoFacts_parking                         0.11055          0.00235
# resoFacts_daysOnZillow                    0.06265          0.02866
# resoFacts_hasAttachedProperty            -0.10838          0.00511
# resoFacts_hasGarage                       0.10013          0.00939
# resoFacts_hasPetsAllowed                  0.05893          0.15027
# resoFacts_hasSpa                         -0.01466         -0.00278
# resoFacts_hasView                         0.00518         -0.06491
# resoFacts_yearBuilt                       0.07690          0.04677
# Elementary_Distance                       0.01991          0.07120
# Elementary_Ratings                        1.00000          0.04688
# Middle_Distance                           0.04688          1.00000
# Middle_Ratings                            0.38731          0.12362
# High_Distance                             0.03511          0.23981
# High_Ratings                              0.27629         -0.00302
# desc_sentiment                           -0.01310         -0.12545
#
#                                Middle_Ratings  High_Distance  High_Ratings  \
# index                                 0.11634        0.20705       0.18765
# lotAreaValue                          0.10692       -0.02418       0.11773
# zestimate                             0.16491       -0.08276       0.04144
# rentZestimate                         0.08041       -0.15074      -0.03252
# livingAreaValue                       0.17356        0.01520       0.07921
# lastSoldPrice                         0.05283       -0.05383      -0.09357
# zestimateLowPercent                   0.00607       -0.19317      -0.16994
# zestimateHighPercent                 -0.04848       -0.14918      -0.20094
# restimateLowPercent                  -0.04265       -0.13473      -0.06618
# restimateHighPercent                 -0.03584       -0.11994      -0.11260
# taxAssessedValue                     -0.03899       -0.00073      -0.02846
# propertyTaxRate                       0.17344        0.35706       0.26099
# resoFacts_hoaFee                     -0.03971       -0.11334       0.02146
# resoFacts_pricePerSquareFoot          0.02098       -0.03023       0.02164
# solarPotential_sunScore               0.00737       -0.01851       0.06467
# bedrooms                              0.17996        0.02816       0.13246
# bathrooms                             0.14633        0.10418       0.14509
# resoFacts_hasFireplace                0.16446        0.00099       0.14487
# resoFacts_parking                     0.10575       -0.17693       0.02774
# resoFacts_daysOnZillow                0.09656        0.10846       0.13835
# resoFacts_hasAttachedProperty        -0.08298       -0.24253      -0.17404
# resoFacts_hasGarage                   0.11440       -0.12492       0.03842
# resoFacts_hasPetsAllowed             -0.02752       -0.02096      -0.07964
# resoFacts_hasSpa                     -0.06931        0.11408       0.02621
# resoFacts_hasView                    -0.06941       -0.02284       0.03736
# resoFacts_yearBuilt                  -0.00415        0.03807       0.01928
# Elementary_Distance                  -0.09329        0.17284       0.00432
# Elementary_Ratings                    0.38731        0.03511       0.27629
# Middle_Distance                       0.12362        0.23981      -0.00302
# Middle_Ratings                        1.00000       -0.05838       0.31597
# High_Distance                        -0.05838        1.00000       0.23353
# High_Ratings                          0.31597        0.23353       1.00000
# desc_sentiment                        0.03974       -0.12556      -0.03078
#
#                                desc_sentiment
# index                                -0.00337
# lotAreaValue                          0.01472
# zestimate                             0.07709
# rentZestimate                         0.09124
# livingAreaValue                       0.05430
# lastSoldPrice                         0.04580
# zestimateLowPercent                   0.03111
# zestimateHighPercent                 -0.02426
# restimateLowPercent                   0.04388
# restimateHighPercent                  0.04893
# taxAssessedValue                     -0.01035
# propertyTaxRate                      -0.07061
# resoFacts_hoaFee                      0.07792
# resoFacts_pricePerSquareFoot         -0.07571
# solarPotential_sunScore               0.03324
# bedrooms                              0.04823
# bathrooms                             0.03883
# resoFacts_hasFireplace                0.12055
# resoFacts_parking                     0.08852
# resoFacts_daysOnZillow               -0.09224
# resoFacts_hasAttachedProperty         0.13217
# resoFacts_hasGarage                   0.07182
# resoFacts_hasPetsAllowed             -0.02168
# resoFacts_hasSpa                     -0.02742
# resoFacts_hasView                     0.08641
# resoFacts_yearBuilt                   0.01743
# Elementary_Distance                  -0.05997
# Elementary_Ratings                   -0.01310
# Middle_Distance                      -0.12545
# Middle_Ratings                        0.03974
# High_Distance                        -0.12556
# High_Ratings                         -0.03078
# desc_sentiment                        1.00000

# %% [markdown]
# # Train-Test Split

# %%
y = df.zestimate

# %%
x= df.drop('zestimate', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2, random_state=123)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (492, 36)
# (492,)
# (123, 36)
# (123,)

# %% [markdown]
# # One Hot Encoding

# %%
df_cat.columns
# Out:
# Index(['city', 'county', 'description', 'parentRegion_name',
#        'resoFacts_flooring', 'schools'],
#       dtype='object')

# %%
cat_columns=['city', 'county']

# %%
from scipy.sparse import coo_matrix

X_train_cat_processed = coo_matrix((492, 0))
X_test_cat_processed = coo_matrix((123, 0))

# %%
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import hstack

from sklearn import preprocessing
vectorizer= preprocessing.OneHotEncoder(handle_unknown = 'ignore')
for x in cat_columns:
    
    
# 1. INSTANTIATE
    
    

        
    one_hot_train = vectorizer.fit_transform(X_train[x].values.reshape(-1,1))
    one_hot_test = vectorizer.transform(X_test[x].values.reshape(-1,1))
    vectorizer.get_feature_names()
    
    X_train_cat_processed= hstack((X_train_cat_processed,one_hot_train)).tocsr()
    X_test_cat_processed= hstack((X_test_cat_processed,one_hot_test)).tocsr()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(X_train_cat_processed.shape)
print(X_test_cat_processed.shape)
# Out:
# (492, 12)
# (123, 12)

# %% [markdown]
# # Numeric Data Preparation

# %%
from scipy.sparse import coo_matrix

X_train_num_processed = coo_matrix((492,0))
X_test_num_processed = coo_matrix((123,0))

# %%
num_cols= [ 'bedrooms','rentZestimate','lastSoldPrice','resoFacts_hasFireplace','Elementary_Ratings','Elementary_Distance',
         'Middle_Ratings', 'High_Ratings','High_Distance' ]

# %%
for x in num_cols:
    

    s_train = (X_train[x].values.reshape(-1, 1))

    s_test = (X_test[x].values.reshape(-1, 1))

    
    X_train_num_processed= hstack((X_train_num_processed,s_train)).tocsr()
    X_test_num_processed= hstack((X_test_num_processed,s_test)).tocsr()

# %%
print(X_train_num_processed.shape)
print(X_test_num_processed.shape)
# Out:
# (492, 9)
# (123, 9)

# %% [markdown]
# # Linear Regression

# %%
from scipy.sparse import hstack
X_train_processed = hstack((X_train_cat_processed,X_train_num_processed )).tocsr()
X_test_processed = hstack(( X_test_cat_processed,X_test_num_processed)).tocsr()
print(X_test_processed.shape)
print(X_train_processed.shape)
# Out:
# (123, 21)
# (492, 21)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train_processed, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = regressor.predict(X_test_processed)

# %%
df_out = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df_out
# Out:
#            Actual     Predicted
# 89  1961900.00000 2366066.59025
# 11  1171700.00000 1320122.58635
# 552 1939700.00000 1783330.24671
# 634 3081600.00000 1710059.33450
# 409 1852800.00000 1873015.09500
# 333 1368600.00000 1467669.89328
# 157 1225500.00000 1205611.61561
# 500  874545.00000 1024132.51544
# 445 1372400.00000 1657476.32225
# 514  840300.00000  955734.02983
# 54   903000.00000 1021192.81068
# 738 2450300.00000 2441253.15990
# 603 2510808.00000 2927570.29230
# 117 1519359.50000 1290490.21976
# 288 1696550.00000 1206187.15775
# 495  841400.00000 1058162.80446
# 227 1554250.00000 1295510.21399
# 426 1112200.00000 1103908.23540
# 193 1083100.00000 1095820.63612
# 557 1958200.00000 1977917.85210
# 205 1177400.00000 1520779.54873
# 462 1216800.00000 1325359.73894
# 716 1478950.00000 1527607.38240
# 85   971000.00000 1100772.94313
# 654 1343000.00000 1536136.21948
# 150 2250400.00000 2979295.09421
# 410 1796748.00000 1918743.43839
# 501  856300.00000 1104907.66381
# 407 1427550.00000 1513042.94516
# 667  984900.00000  622667.88661
# 525 1168300.00000 1195586.75189
# 60  1707800.00000 1571217.84741
# 328 1803200.00000 1773682.95768
# 195 2622000.00000 4567751.11624
# 174 1963673.50000 1538484.36384
# 703 1291600.00000 1180996.12324
# 646 1514941.00000 1085957.25301
# 591 1534615.00000 1420109.83909
# 447  694950.00000  879215.03711
# 247 1212650.00000 1574301.48697
# 334 1479000.00000 1334811.79039
# 39   985800.00000 1314041.18355
# 47  1428800.00000 1504031.60410
# 464  953000.00000  946228.82816
# 383  951500.00000  897003.79762
# 476 5481200.00000 4056031.33697
# 378  681500.00000  767814.54763
# 729 1486503.00000 1317213.64879
# 403 3980800.00000 3247273.24623
# 453 1155200.00000 1171127.61811
# 434  691800.00000  636943.35900
# 9   1332300.00000 1608686.52027
# 146 1300400.00000 1382145.28058
# 275 2504000.00000 2083840.19137
# 599 1137415.00000 1542831.58951
# 243 1249100.00000 1359800.02270
# 63  2216600.00000 1233916.86644
# 664 1699500.00000 1631604.24925
# 335 3871700.00000 3838377.62532
# 291 3031000.00000 4871631.09148
# 630 1190366.00000 1300147.18896
# 5   1331100.00000 1611602.70857
# 307 2157500.00000 2628510.08845
# 610 1594100.00000 1934690.24957
# 244 2251900.00000 1512907.85259
# 109  557900.00000  738420.56154
# 180 1442300.00000  867941.01491
# 31  1681600.00000 1676481.89568
# 680 3589724.00000 2664136.47793
# 198  759300.00000  773041.22235
# 606 2659111.00000 2715327.92724
# 319 4905100.00000 4284744.48164
# 148 2266000.00000 1987952.43688
# 348 2236900.00000 2594430.39962
# 638 1150500.00000 1289858.36979
# 726 2895500.00000 3613698.49045
# 736 1296810.00000 1506090.56872
# 72  1493800.00000 1560947.23180
# 245 2475900.00000 2636926.05882
# 671 1252500.00000 1129372.09632
# 379 1302500.00000  982239.12161
# 274 9668600.00000 4373895.51262
# 204 1438800.00000 1162800.13220
# 612 1673420.00000 2327071.79532
# 82  1012700.00000  795087.81517
# 280  969700.00000 1131419.15286
# 387 1284700.00000 1678233.12111
# 13  1450500.00000 1587919.14313
# 689 1366600.00000 1691254.45467
# 352 4650000.00000 4547225.70326
# 365 2157500.00000 2471530.41777
# 498 1034283.00000 1314310.95827
# 316 1195050.00000 1357572.71566
# 86  1131800.00000 1339651.71538
# 633 1371386.00000 1435975.86312
# 708 1281300.00000 1176823.47571
# 345  922300.00000 1514269.35430
# 582 2380300.00000 2214453.17859
# 184 2929800.00000 3161911.25207
# 240 1592500.00000 1722556.88839
# 532 1065800.00000 1196913.23834
# 713 1720600.00000 1613211.33356
# 254 1577300.00000 1549726.01614
# 684 1766300.00000 1608472.01638
# 408 1763600.00000 1750652.92902
# 597 2786147.00000 2095147.50933
# 92  3217300.00000 2925065.15230
# 546  960064.00000 1241562.85297
# 176 1726200.00000 1850263.54389
# 337  894400.00000  854958.25468
# 541 2637300.00000 2200308.82718
# 65  1217200.00000 1391952.07447
# 472 1262900.00000 1173419.63478
# 273  894400.00000  715307.51054
# 411  690433.00000 1175707.61492
# 40   715500.00000  910476.73862
# 714 1480900.00000 1409548.07856
# 668 1721200.00000 1637082.03845
# 706 1637100.00000 1458598.00862
# 427 1251800.00000 1039271.46503
# 299 2630900.00000 3131575.89965
# 678 1011500.00000 1127051.12144
# 699 1565431.00000 1524051.04182

# %%
from sklearn.metrics import r2_score
r2_score =r2_score(Y_test, Y_pred)
rows , col =X_train_processed.shape
adj_R2 = 1- ((1-r2_score) * (rows-1)/(rows-col-1)) #Adj R2 = 1-(1-R2)*(n-1)/(n-p-1)
print('R2 is:', r2_score.round(4))
print('Adjusted R2 is:', adj_R2.round(3))
# Out:
# R2 is: 0.6742
# Adjusted R2 is: 0.66

# %% [markdown]
# # OLS regresssion

# %%
X_train_test_processed=pd.concat([pd.DataFrame(X_train_processed.todense()),pd.DataFrame(X_test_processed.todense())],ignore_index=True)
Y_train_test_processed = pd.concat([pd.DataFrame(Y_train),pd.DataFrame(Y_test)], ignore_index=True)

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats


X2 = sm.add_constant(X_train_test_processed)
est = sm.OLS(Y_train_test_processed, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              zestimate   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     117.4
# Date:                Mon, 04 Apr 2022   Prob (F-statistic):          2.82e-182
# Time:                        13:24:52   Log-Likelihood:                -8885.0
# No. Observations:                 615   AIC:                         1.781e+04
# Df Residuals:                     596   BIC:                         1.789e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.636e+05   1.17e+05     -3.119      0.002   -5.93e+05   -1.35e+05
# 0          -1.854e+05   1.26e+05     -1.470      0.142   -4.33e+05    6.23e+04
# 1          -2.443e+05   3.86e+05     -0.633      0.527      -1e+06    5.14e+05
# 2            1.33e+05   9.68e+04      1.374      0.170   -5.71e+04    3.23e+05
# 3           5.017e+04   1.06e+05      0.474      0.636   -1.58e+05    2.58e+05
# 4           5.338e+05   2.36e+05      2.266      0.024    7.11e+04    9.97e+05
# 5          -3460.4241   1.11e+05     -0.031      0.975   -2.22e+05    2.15e+05
# 6          -8.973e+04   3.88e+04     -2.313      0.021   -1.66e+05   -1.35e+04
# 7          -8.548e+04   2.17e+05     -0.393      0.694   -5.12e+05    3.41e+05
# 8           5.042e+04   2.18e+05      0.232      0.817   -3.77e+05    4.78e+05
# 9            -2.5e+05   8.86e+04     -2.823      0.005   -4.24e+05   -7.61e+04
# 10         -8.973e+04   3.88e+04     -2.313      0.021   -1.66e+05   -1.35e+04
# 11         -2.387e+04   1.55e+05     -0.154      0.878   -3.29e+05    2.81e+05
# 12          9.644e+04   1.69e+04      5.715      0.000    6.33e+04     1.3e+05
# 13           287.8739      9.404     30.611      0.000     269.405     306.343
# 14             0.1686      0.026      6.407      0.000       0.117       0.220
# 15          7.182e+04   4.15e+04      1.732      0.084   -9617.099    1.53e+05
# 16          2185.5038   1.08e+04      0.203      0.839    -1.9e+04    2.34e+04
# 17         -8.332e+04   6.21e+04     -1.342      0.180   -2.05e+05    3.86e+04
# 18          3.462e+04   1.29e+04      2.692      0.007    9364.054    5.99e+04
# 19          1.981e+04   1.32e+04      1.505      0.133   -6048.281    4.57e+04
# 20         -4596.2841   2.57e+04     -0.179      0.858   -5.51e+04    4.59e+04
# ==============================================================================
# Omnibus:                      388.918   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21933.128
# Skew:                           2.072   Prob(JB):                         0.00
# Kurtosis:                      31.961   Cond. No.                     2.29e+22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.38e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
 # [ starts from index 12- 'bedrooms','rentZestimate','lastSoldPrice','resoFacts_hasFireplace','Elementary_Ratings','Elementary_Distance',
 #        'Middle_Ratings','High_Ratings','High_Distance' ]
