# %%
import pandas as pd
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
pd.set_option('display.max_colwidth',None)
import re
import ast
import numpy as np
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df = pd.read_excel ('Tier B.xlsx')

# %%
a=['countyId','zipcode', 'zestimate','lotAreaValue',
       'rentZestimate','bedrooms', 'bathrooms', 'livingAreaValue', 
       'lastSoldPrice', 'zestimateLowPercent', 'zestimateHighPercent',
       'restimateLowPercent', 'restimateHighPercent', 
       'taxAssessedValue', 'taxAssessedYear', 
       'propertyTaxRate',  
       'resoFacts_hasFireplace', 'resoFacts_parking',
       'mortgageRates_thirtyYearFixedRate',
       'mortgageRates_fifteenYearFixedRate', 'mortgageRates_arm5Rate', 
    'city', 'county' , 'description','parentRegion_name',
    'dateSoldString', 'resoFacts_daysOnZillow', 'resoFacts_flooring', 'resoFacts_hasAttachedProperty',
    'resoFacts_hasGarage', 'resoFacts_hasPetsAllowed', 'resoFacts_hasSpa' , 'resoFacts_hasView','resoFacts_hoaFee',
     'resoFacts_pricePerSquareFoot','resoFacts_yearBuilt' ,'solarPotential_sunScore','schools'
   ]

# %%
df=df[a]

# %%
df.shape
# Out:
# (819, 38)

# %%
df.isnull().sum().sum()
# Out:
# 2565

# %%
df.head(1)
# Out:
#    countyId  zipcode     zestimate  lotAreaValue  rentZestimate  bedrooms  \
# 0      3136    95111 1006033.00000    5553.00000     3494.00000   3.00000
#
#    bathrooms  livingAreaValue  lastSoldPrice  zestimateLowPercent  \
# 0    2.00000       1206.00000   320000.00000              7.00000
#
#    zestimateHighPercent  restimateLowPercent  restimateHighPercent  \
# 0               6.00000              8.00000               6.00000
#
#    taxAssessedValue  taxAssessedYear  propertyTaxRate  resoFacts_hasFireplace  \
# 0      376786.00000       2020.00000          0.77000                 1.00000
#
#    resoFacts_parking  mortgageRates_thirtyYearFixedRate  \
# 0                  0                            2.78500
#
#    mortgageRates_fifteenYearFixedRate  mortgageRates_arm5Rate      city  \
# 0                             2.08000                 2.62900  San Jose
#
#                county  \
# 0  Santa Clara County
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     description  \
# 0  1206 Square Foot Home with 3 bedrooms 2 baths very well taken care of.  1 master bedroom with own bathroom and 2 amply large rooms and 1 hallway bathroom.  5600 SF lot with nice yard A Must see.  In Addition to 3/2 house also has a Converted Garage (1 bedroom 1 full bath and kitchen) currently renting for $1750/month. Also 1 bedroom in the back with half bath and 1 bedroom with a full bath currently not rented.  Live in the house and generate rental income in other units.
#
#         parentRegion_name dateSoldString  resoFacts_daysOnZillow  \
# 0  Edenvale - Seven Trees     2008-08-14                 0.00000
#
#   resoFacts_flooring  resoFacts_hasAttachedProperty  resoFacts_hasGarage  \
# 0                 []                              0                    0
#
#    resoFacts_hasPetsAllowed  resoFacts_hasSpa  resoFacts_hasView  \
# 0                         0                 0                  0
#
#   resoFacts_hoaFee  resoFacts_pricePerSquareFoot  resoFacts_yearBuilt  \
# 0              NaN                     771.00000           1960.00000
#
#    solarPotential_sunScore  \
# 0                 94.45000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                schools
# 0  [{'distance': 0.3, 'name': 'Edenvale Elementary', 'rating': 3, 'level': 'Elementary', 'studentsPerTeacher': 23, 'assigned': None, 'grades': 'K-6', 'link': 'https://www.greatschools.org/school?id=05589&state=CA', 'type': 'Public', 'size': 485, 'totalCount': 1, 'isAssigned': True}, {'distance': 0.4, 'name': 'Davis (Caroline) Intermediate', 'rating': 3, 'level': 'Middle', 'studentsPerTeacher': 20, 'assigned': None, 'grades': '7-8', 'link': 'https://www.greatschools.org/school?id=05587&state=CA', 'type': 'Public', 'size': 596, 'totalCount': 1, 'isAssigned': True}, {'distance': 1, 'name': 'Oak Grove High', 'rating': 5, 'level': 'High', 'studentsPerTeacher': 23, 'assigned': None, 'grades': '9-12', 'link': 'https://www.greatschools.org/school?id=05459&state=CA', 'type': 'Public', 'size': 1766, 'totalCount': 1, 'isAssigned': True}]

# %% [markdown]
# # Data Cleaning and Null Values removal

# %%
df['resoFacts_hoaFee'].fillna(df['resoFacts_hoaFee'].mode()[0], inplace=True)
hoe=[]
for x in df['resoFacts_hoaFee']:
    x=str(x).replace(",","")
    hoe.append(int(re.findall('[0-9,]+', x)[0]))
df['resoFacts_hoaFee']=hoe

# %%
df['resoFacts_flooring'].fillna(df['resoFacts_flooring'].mode()[0], inplace=True)
flooring=[]
for x in df['resoFacts_flooring']:
    x=x.replace('[',"")
    flooring.append(x.replace(']',""))
df['resoFacts_flooring']= flooring

# %%
df_cat= df.select_dtypes(exclude='number')
print(df_cat.shape)
# Out:
# (819, 7)

# %%
print(df_cat.isnull().sum())
# Out:
# city                    0
# county                  0
# description             4
# parentRegion_name       0
# dateSoldString        183
# resoFacts_flooring      0
# schools                 1
# dtype: int64

# %%
for column in df_cat:
    df_cat[column].fillna(df_cat[column].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
print(df_cat.isnull().sum().sum())
# Out:
# 0

# %%
discrete_cols= ["bedrooms", "bathrooms", "resoFacts_hasFireplace", "resoFacts_parking", "resoFacts_daysOnZillow" ,"resoFacts_hasAttachedProperty" , "resoFacts_hasGarage" , "resoFacts_hasPetsAllowed", "resoFacts_hasSpa", "resoFacts_hasView", "resoFacts_yearBuilt"]

# %%
numeric_cols=["lotAreaValue","zestimate","rentZestimate", "livingAreaValue", "lastSoldPrice", "zestimateLowPercent", "zestimateHighPercent", "restimateLowPercent" ,"restimateHighPercent" , "taxAssessedValue" , "propertyTaxRate", "resoFacts_hoaFee", "resoFacts_pricePerSquareFoot" , "solarPotential_sunScore"]

# %%
df_discrete=df[discrete_cols]
df_num=df[numeric_cols]

# %%
df_num.isnull().sum()
# Out:
# lotAreaValue                     85
# zestimate                       116
# rentZestimate                    50
# livingAreaValue                  22
# lastSoldPrice                   183
# zestimateLowPercent             116
# zestimateHighPercent            116
# restimateLowPercent             164
# restimateHighPercent            164
# taxAssessedValue                 94
# propertyTaxRate                   1
# resoFacts_hoaFee                  0
# resoFacts_pricePerSquareFoot     24
# solarPotential_sunScore         107
# dtype: int64

# %%
from sklearn.impute import KNNImputer   # missing values imputation

imputer = KNNImputer(n_neighbors=2)  #impute missing values
df_num.iloc[:,0:]=imputer.fit_transform(df_num.iloc[:,0:]) #replace df with imputed missing values
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
df_num.isnull().sum().sum()
# Out:
# 0

# %%
df_discrete.isnull().sum()
# Out:
# bedrooms                          39
# bathrooms                         23
# resoFacts_hasFireplace           144
# resoFacts_parking                  0
# resoFacts_daysOnZillow             1
# resoFacts_hasAttachedProperty      0
# resoFacts_hasGarage                0
# resoFacts_hasPetsAllowed           0
# resoFacts_hasSpa                   0
# resoFacts_hasView                  0
# resoFacts_yearBuilt               21
# dtype: int64

# %%
#df_discret= df_discrete.dropna()

# %%
df_discrete.resoFacts_hasFireplace.value_counts()
# Out:
# 1.00000    481
# 0.00000    194
# Name: resoFacts_hasFireplace, dtype: int64

# %%
df_discrete['resoFacts_hasFireplace'].fillna(0, inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df_discrete.isnull().sum()
# Out:
# bedrooms                         39
# bathrooms                        23
# resoFacts_hasFireplace            0
# resoFacts_parking                 0
# resoFacts_daysOnZillow            1
# resoFacts_hasAttachedProperty     0
# resoFacts_hasGarage               0
# resoFacts_hasPetsAllowed          0
# resoFacts_hasSpa                  0
# resoFacts_hasView                 0
# resoFacts_yearBuilt              21
# dtype: int64

# %%
for column in df_discrete:
    df_discrete[column].fillna(df_discrete[column].mode()[0], inplace=True)

# %%
df_discrete.isnull().sum()
# Out:
# bedrooms                         0
# bathrooms                        0
# resoFacts_hasFireplace           0
# resoFacts_parking                0
# resoFacts_daysOnZillow           0
# resoFacts_hasAttachedProperty    0
# resoFacts_hasGarage              0
# resoFacts_hasPetsAllowed         0
# resoFacts_hasSpa                 0
# resoFacts_hasView                0
# resoFacts_yearBuilt              0
# dtype: int64

# %%
print(df_cat.shape)
print(df_num.shape)
print(df_discrete.shape)
# Out:
# (819, 7)
# (819, 14)
# (819, 11)

# %%
df_discrete['resoFacts_parking']=np.where(df_discrete['resoFacts_parking']>=1,1,0)
# Out:
# <ipython-input-299-4ece1c62a106>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_discrete['resoFacts_parking']=np.where(df_discrete['resoFacts_parking']>=1,1,0)

# %%
df_discrete.resoFacts_parking.value_counts()
# Out:
# 0    417
# 1    402
# Name: resoFacts_parking, dtype: int64

# %%
df= pd.concat([df_cat,df_num,df_discrete], axis=1)  # this df is without outliers and without null values

# %%
df.shape
# Out:
# (819, 32)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Feature Engineering- Creating 6 features out of school

# %%
#df_2= pd.read_excel('zillow_full.xlsx')

# %%
schools= list(df['schools'])

# %%
list_schools= [[]] * len(schools)

# %%
len(list_schools)
# Out:
# 819

# %%
i=0
for x in schools:
    list_schools[i]=[0,0,0,0,0,0]
    x = str(x).replace('\\','"')
    l=re.findall("[{][\\a-zA-z0-9:',\-/ \.=?&]+[}]", x)
    for y in l:
        y=ast.literal_eval(y)
        if y['level']== 'Elementary':
            if y['rating']!=None:
                if list_schools[i][1]<y['rating']:
                    list_schools[i][1]=y['rating']
                    list_schools[i][0]=y['distance']
                
        if y['level']== 'Middle':
            if y['rating']!=None:
                if list_schools[i][3]<y['rating']:
                    list_schools[i][3]=y['rating']
                    list_schools[i][2]=y['distance']
        if y['level']=='High':
            if y['rating']!=None:
                if list_schools[i][5]<y['rating']:
                    list_schools[i][5]=y['rating']
                    list_schools[i][4]=y['distance']
    
    i+=1

# %%
list_schools[0]
# Out:
# [0.3, 3, 0.4, 3, 1, 5]

# %%
for i in range(len(list_schools)):
    list_schools[i] = [None if item <=0 else item for item in list_schools[i]]

# %%
df_3 = pd.DataFrame(list_schools, columns = ['Elementary_Distance', 'Elementary_Ratings', 'Middle_Distance', 'Middle_Ratings', 'High_Distance', 'High_Ratings'])

# %%
df_3['Elementary_Distance']=np.where(np.isnan(df_3['Elementary_Distance']),df_3['Elementary_Distance'].median(),df_3['Elementary_Distance']) 
df_3['Middle_Ratings']=np.where(np.isnan(df_3['Middle_Ratings']),df_3['Middle_Ratings'].mode(),df_3['Middle_Ratings']) 
df_3['Middle_Distance']=np.where(np.isnan(df_3['Middle_Distance']),df_3['Middle_Distance'].median(),df_3['Middle_Distance']) 
df_3['High_Ratings']=np.where(np.isnan(df_3['High_Ratings']),df_3['High_Ratings'].mode(),df_3['High_Ratings']) 
df_3['High_Distance']=np.where(np.isnan(df_3['High_Distance']),df_3['High_Distance'].median(),df_3['High_Distance'])

# %%
imputer = KNNImputer(n_neighbors=2)  #impute missing values
df_3.iloc[:,0:]=imputer.fit_transform(df_3.iloc[:,0:]) #replace df with imputed missing values

# %%
df_3.shape
# Out:
# (819, 6)

# %%
df_3.isnull().sum()
# Out:
# Elementary_Distance    0
# Elementary_Ratings     0
# Middle_Distance        0
# Middle_Ratings         0
# High_Distance          0
# High_Ratings           0
# dtype: int64

# %%
df.shape
# Out:
# (819, 32)

# %%
df.drop('schools', axis=1, inplace= True)

# %%
df.shape
# Out:
# (819, 31)

# %%
df=df.reset_index()

# %%
df=pd.concat([df,df_3], axis=1)

# %%
df.shape  # this df contains school columns also
# Out:
# (819, 38)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Outliers

# %%
columns_for_outliers=[ 'Elementary_Ratings','Elementary_Distance',
       'Middle_Ratings','Middle_Distance', 'High_Distance', 'High_Ratings']

# %%
# Detecting outliers and imputing nan 
from scipy.stats import skew

for x in columns_for_outliers:
        percentile25 = df[x].quantile(0.25)
        percentile75 = df[x].quantile(0.75)
        iqr= percentile75-percentile25
        upper = percentile75 + 1.5 * iqr
        lower = percentile25 - 1.5 * iqr
        for y in df[x]:
            if (y>upper) or (y<lower):
                df[x].loc[df[x] == y]=None
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df.isnull().sum()
# Out:
# index                             0
# city                              0
# county                            0
# description                       0
# parentRegion_name                 0
# dateSoldString                    0
# resoFacts_flooring                0
# lotAreaValue                      0
# zestimate                         0
# rentZestimate                     0
# livingAreaValue                   0
# lastSoldPrice                     0
# zestimateLowPercent               0
# zestimateHighPercent              0
# restimateLowPercent               0
# restimateHighPercent              0
# taxAssessedValue                  0
# propertyTaxRate                   0
# resoFacts_hoaFee                  0
# resoFacts_pricePerSquareFoot      0
# solarPotential_sunScore           0
# bedrooms                          0
# bathrooms                         0
# resoFacts_hasFireplace            0
# resoFacts_parking                 0
# resoFacts_daysOnZillow            0
# resoFacts_hasAttachedProperty     0
# resoFacts_hasGarage               0
# resoFacts_hasPetsAllowed          0
# resoFacts_hasSpa                  0
# resoFacts_hasView                 0
# resoFacts_yearBuilt               0
# Elementary_Distance              47
# Elementary_Ratings                0
# Middle_Distance                  66
# Middle_Ratings                   12
# High_Distance                    49
# High_Ratings                      7
# dtype: int64

# %%
df= df.dropna()

# %%
df.shape
# Out:
# (678, 38)

# %% [markdown]
# # Feature Engineering- Creating New feature out of feature("description")

# %%
sentiment_des = []
from textblob import TextBlob
for text in df['description'].values:
        t= TextBlob(text)
        sentiment_des.append(t.sentiment[0])
df['desc_sentiment']=sentiment_des

# %%
df['desc_sentiment']=sentiment_des

# %%
df.drop(['description'], axis=1,inplace=True)

# %%
df.shape
# Out:
# (678, 38)

# %%
df.corr()
# Out:
#                                  index  lotAreaValue  zestimate  \
# index                          1.00000      -0.10713   -0.30906
# lotAreaValue                  -0.10713       1.00000    0.32500
# zestimate                     -0.30906       0.32500    1.00000
# rentZestimate                 -0.18556       0.26399    0.75789
# livingAreaValue               -0.06375       0.21102    0.59905
# lastSoldPrice                 -0.09970       0.21585    0.44930
# zestimateLowPercent            0.01283       0.08240    0.01766
# zestimateHighPercent          -0.00682       0.12986    0.11320
# restimateLowPercent           -0.03664      -0.03433    0.13315
# restimateHighPercent           0.05431      -0.02865    0.06119
# taxAssessedValue              -0.14955       0.05669    0.51303
# propertyTaxRate                0.76615      -0.11234   -0.35805
# resoFacts_hoaFee               0.04178      -0.04187   -0.10835
# resoFacts_pricePerSquareFoot  -0.26980       0.11104    0.42862
# solarPotential_sunScore        0.03658      -0.11451   -0.03157
# bedrooms                      -0.00561       0.30689    0.48501
# bathrooms                      0.01296       0.03089    0.44106
# resoFacts_hasFireplace        -0.15768       0.25307    0.33429
# resoFacts_parking              0.31380      -0.05714   -0.07445
# resoFacts_daysOnZillow         0.15198       0.00984    0.05488
# resoFacts_hasAttachedProperty  0.01802      -0.15409   -0.08200
# resoFacts_hasGarage            0.38172      -0.02693   -0.05185
# resoFacts_hasPetsAllowed       0.15006      -0.16584   -0.17733
# resoFacts_hasSpa              -0.13728      -0.00065    0.10638
# resoFacts_hasView             -0.06599       0.01008    0.12234
# resoFacts_yearBuilt           -0.01326       0.02352    0.08211
# Elementary_Distance           -0.17892      -0.11464    0.01973
# Elementary_Ratings            -0.29558       0.10353    0.35018
# Middle_Distance               -0.01661      -0.01933    0.04240
# Middle_Ratings                -0.35118       0.15924    0.33472
# High_Distance                  0.00025       0.04215    0.07586
# High_Ratings                  -0.32074       0.14232    0.36674
# desc_sentiment                 0.02371       0.02916   -0.01218
#
#                                rentZestimate  livingAreaValue  lastSoldPrice  \
# index                               -0.18556         -0.06375       -0.09970
# lotAreaValue                         0.26399          0.21102        0.21585
# zestimate                            0.75789          0.59905        0.44930
# rentZestimate                        1.00000          0.54723        0.42702
# livingAreaValue                      0.54723          1.00000        0.36828
# lastSoldPrice                        0.42702          0.36828        1.00000
# zestimateLowPercent                  0.01764          0.08483        0.02762
# zestimateHighPercent                 0.09399          0.20920        0.07341
# restimateLowPercent                  0.16584          0.23796        0.07803
# restimateHighPercent                 0.05071          0.28079        0.06808
# taxAssessedValue                     0.38427          0.34507        0.45482
# propertyTaxRate                     -0.17793         -0.01402       -0.14545
# resoFacts_hoaFee                    -0.10365         -0.09896       -0.08837
# resoFacts_pricePerSquareFoot         0.08114         -0.21633        0.09963
# solarPotential_sunScore              0.00436          0.04204       -0.06159
# bedrooms                             0.48989          0.66112        0.30185
# bathrooms                            0.54660          0.55638        0.27453
# resoFacts_hasFireplace               0.38742          0.12320        0.14252
# resoFacts_parking                    0.05653          0.05215        0.00297
# resoFacts_daysOnZillow               0.00909         -0.01365        0.07189
# resoFacts_hasAttachedProperty       -0.03051         -0.05157       -0.06022
# resoFacts_hasGarage                  0.07213          0.08407        0.01616
# resoFacts_hasPetsAllowed            -0.13435         -0.09191       -0.13193
# resoFacts_hasSpa                     0.10743          0.06401       -0.01884
# resoFacts_hasView                    0.14817          0.07204        0.11179
# resoFacts_yearBuilt                  0.06761          0.10245        0.07776
# Elementary_Distance                 -0.02634         -0.02906        0.04842
# Elementary_Ratings                   0.27160          0.11201        0.16031
# Middle_Distance                      0.01127          0.00658        0.04033
# Middle_Ratings                       0.22306          0.09481        0.13060
# High_Distance                        0.07682          0.09763        0.11260
# High_Ratings                         0.22170          0.14976        0.16161
# desc_sentiment                       0.00322         -0.05240       -0.01013
#
#                                zestimateLowPercent  zestimateHighPercent  \
# index                                      0.01283              -0.00682
# lotAreaValue                               0.08240               0.12986
# zestimate                                  0.01766               0.11320
# rentZestimate                              0.01764               0.09399
# livingAreaValue                            0.08483               0.20920
# lastSoldPrice                              0.02762               0.07341
# zestimateLowPercent                        1.00000               0.88412
# zestimateHighPercent                       0.88412               1.00000
# restimateLowPercent                        0.11505               0.21065
# restimateHighPercent                       0.18014               0.29432
# taxAssessedValue                          -0.18457              -0.09968
# propertyTaxRate                            0.24216               0.25487
# resoFacts_hoaFee                           0.11897               0.16207
# resoFacts_pricePerSquareFoot              -0.04006              -0.03087
# solarPotential_sunScore                   -0.11085              -0.12979
# bedrooms                                   0.03890               0.12909
# bathrooms                                 -0.04626               0.01819
# resoFacts_hasFireplace                    -0.02600              -0.00719
# resoFacts_parking                          0.10282               0.11471
# resoFacts_daysOnZillow                    -0.04140              -0.05103
# resoFacts_hasAttachedProperty             -0.07675              -0.07635
# resoFacts_hasGarage                        0.13798               0.14050
# resoFacts_hasPetsAllowed                   0.02747               0.02088
# resoFacts_hasSpa                          -0.06322              -0.07095
# resoFacts_hasView                          0.00108               0.02100
# resoFacts_yearBuilt                       -0.06393              -0.08341
# Elementary_Distance                       -0.07635              -0.08349
# Elementary_Ratings                        -0.12080              -0.07910
# Middle_Distance                           -0.07690              -0.09498
# Middle_Ratings                            -0.10078              -0.08855
# High_Distance                             -0.04210              -0.02877
# High_Ratings                              -0.10004              -0.10134
# desc_sentiment                            -0.05189              -0.02219
#
#                                restimateLowPercent  restimateHighPercent  \
# index                                     -0.03664               0.05431
# lotAreaValue                              -0.03433              -0.02865
# zestimate                                  0.13315               0.06119
# rentZestimate                              0.16584               0.05071
# livingAreaValue                            0.23796               0.28079
# lastSoldPrice                              0.07803               0.06808
# zestimateLowPercent                        0.11505               0.18014
# zestimateHighPercent                       0.21065               0.29432
# restimateLowPercent                        1.00000               0.43276
# restimateHighPercent                       0.43276               1.00000
# taxAssessedValue                           0.18011               0.08622
# propertyTaxRate                            0.07816               0.25378
# resoFacts_hoaFee                           0.04122               0.09512
# resoFacts_pricePerSquareFoot              -0.11307              -0.17439
# solarPotential_sunScore                   -0.01450              -0.00374
# bedrooms                                   0.15831               0.11773
# bathrooms                                  0.14369               0.04170
# resoFacts_hasFireplace                    -0.07204              -0.16275
# resoFacts_parking                          0.01335               0.09191
# resoFacts_daysOnZillow                    -0.02438              -0.02904
# resoFacts_hasAttachedProperty              0.05390               0.00908
# resoFacts_hasGarage                        0.02485               0.06774
# resoFacts_hasPetsAllowed                   0.05409               0.06987
# resoFacts_hasSpa                           0.00635              -0.04844
# resoFacts_hasView                          0.07405              -0.02543
# resoFacts_yearBuilt                       -0.04098              -0.09494
# Elementary_Distance                       -0.01130              -0.02233
# Elementary_Ratings                         0.01605              -0.06694
# Middle_Distance                            0.00561              -0.01824
# Middle_Ratings                            -0.03010              -0.13858
# High_Distance                              0.00677               0.04170
# High_Ratings                              -0.01194              -0.06189
# desc_sentiment                            -0.03481               0.03555
#
#                                taxAssessedValue  propertyTaxRate  \
# index                                  -0.14955          0.76615
# lotAreaValue                            0.05669         -0.11234
# zestimate                               0.51303         -0.35805
# rentZestimate                           0.38427         -0.17793
# livingAreaValue                         0.34507         -0.01402
# lastSoldPrice                           0.45482         -0.14545
# zestimateLowPercent                    -0.18457          0.24216
# zestimateHighPercent                   -0.09968          0.25487
# restimateLowPercent                     0.18011          0.07816
# restimateHighPercent                    0.08622          0.25378
# taxAssessedValue                        1.00000         -0.15973
# propertyTaxRate                        -0.15973          1.00000
# resoFacts_hoaFee                       -0.12322          0.12687
# resoFacts_pricePerSquareFoot            0.19026         -0.34674
# solarPotential_sunScore                 0.02171          0.04525
# bedrooms                                0.17553         -0.04494
# bathrooms                               0.27804         -0.04163
# resoFacts_hasFireplace                  0.09084         -0.19459
# resoFacts_parking                       0.02309          0.46351
# resoFacts_daysOnZillow                  0.09023         -0.00292
# resoFacts_hasAttachedProperty           0.01587          0.06176
# resoFacts_hasGarage                     0.00458          0.51708
# resoFacts_hasPetsAllowed               -0.06730          0.24365
# resoFacts_hasSpa                        0.05057         -0.19052
# resoFacts_hasView                       0.14134          0.01645
# resoFacts_yearBuilt                     0.02776         -0.09241
# Elementary_Distance                     0.08329         -0.22192
# Elementary_Ratings                      0.17767         -0.38394
# Middle_Distance                         0.03428         -0.13102
# Middle_Ratings                          0.10995         -0.45131
# High_Distance                           0.10581         -0.06239
# High_Ratings                            0.13467         -0.47364
# desc_sentiment                          0.00151          0.02604
#
#                                resoFacts_hoaFee  resoFacts_pricePerSquareFoot  \
# index                                   0.04178                      -0.26980
# lotAreaValue                           -0.04187                       0.11104
# zestimate                              -0.10835                       0.42862
# rentZestimate                          -0.10365                       0.08114
# livingAreaValue                        -0.09896                      -0.21633
# lastSoldPrice                          -0.08837                       0.09963
# zestimateLowPercent                     0.11897                      -0.04006
# zestimateHighPercent                    0.16207                      -0.03087
# restimateLowPercent                     0.04122                      -0.11307
# restimateHighPercent                    0.09512                      -0.17439
# taxAssessedValue                       -0.12322                       0.19026
# propertyTaxRate                         0.12687                      -0.34674
# resoFacts_hoaFee                        1.00000                      -0.00751
# resoFacts_pricePerSquareFoot           -0.00751                       1.00000
# solarPotential_sunScore                 0.01707                      -0.12723
# bedrooms                               -0.16548                      -0.13667
# bathrooms                              -0.18795                      -0.19031
# resoFacts_hasFireplace                  0.02768                       0.11744
# resoFacts_parking                       0.07703                      -0.14756
# resoFacts_daysOnZillow                  0.00101                       0.09359
# resoFacts_hasAttachedProperty           0.09787                      -0.02423
# resoFacts_hasGarage                     0.08211                      -0.14637
# resoFacts_hasPetsAllowed                0.15421                      -0.10929
# resoFacts_hasSpa                        0.01956                      -0.00174
# resoFacts_hasView                       0.03095                       0.01003
# resoFacts_yearBuilt                     0.01604                      -0.00121
# Elementary_Distance                    -0.00907                       0.01499
# Elementary_Ratings                      0.01566                       0.20334
# Middle_Distance                        -0.01745                       0.03377
# Middle_Ratings                         -0.10960                       0.22537
# High_Distance                          -0.15992                      -0.02181
# High_Ratings                           -0.13740                       0.21590
# desc_sentiment                          0.03419                      -0.04167
#
#                                solarPotential_sunScore  bedrooms  bathrooms  \
# index                                          0.03658  -0.00561    0.01296
# lotAreaValue                                  -0.11451   0.30689    0.03089
# zestimate                                     -0.03157   0.48501    0.44106
# rentZestimate                                  0.00436   0.48989    0.54660
# livingAreaValue                                0.04204   0.66112    0.55638
# lastSoldPrice                                 -0.06159   0.30185    0.27453
# zestimateLowPercent                           -0.11085   0.03890   -0.04626
# zestimateHighPercent                          -0.12979   0.12909    0.01819
# restimateLowPercent                           -0.01450   0.15831    0.14369
# restimateHighPercent                          -0.00374   0.11773    0.04170
# taxAssessedValue                               0.02171   0.17553    0.27804
# propertyTaxRate                                0.04525  -0.04494   -0.04163
# resoFacts_hoaFee                               0.01707  -0.16548   -0.18795
# resoFacts_pricePerSquareFoot                  -0.12723  -0.13667   -0.19031
# solarPotential_sunScore                        1.00000   0.00755    0.00918
# bedrooms                                       0.00755   1.00000    0.65504
# bathrooms                                      0.00918   0.65504    1.00000
# resoFacts_hasFireplace                         0.02920   0.14923    0.12261
# resoFacts_parking                              0.09393   0.00682    0.10485
# resoFacts_daysOnZillow                        -0.00639   0.00806    0.00799
# resoFacts_hasAttachedProperty                  0.04455  -0.09087   -0.01037
# resoFacts_hasGarage                            0.08121   0.02943    0.11161
# resoFacts_hasPetsAllowed                       0.06988  -0.15079   -0.06313
# resoFacts_hasSpa                               0.00710   0.03671    0.10442
# resoFacts_hasView                              0.01897   0.03694    0.07393
# resoFacts_yearBuilt                            0.06252   0.02912    0.04917
# Elementary_Distance                           -0.01111  -0.11862   -0.02765
# Elementary_Ratings                             0.00042   0.01938    0.10741
# Middle_Distance                               -0.00912   0.00901    0.01288
# Middle_Ratings                                -0.00466   0.12712    0.08284
# High_Distance                                  0.02883   0.06917    0.06827
# High_Ratings                                  -0.01237   0.15454    0.10687
# desc_sentiment                                 0.05789  -0.01873   -0.01836
#
#                                resoFacts_hasFireplace  resoFacts_parking  \
# index                                        -0.15768            0.31380
# lotAreaValue                                  0.25307           -0.05714
# zestimate                                     0.33429           -0.07445
# rentZestimate                                 0.38742            0.05653
# livingAreaValue                               0.12320            0.05215
# lastSoldPrice                                 0.14252            0.00297
# zestimateLowPercent                          -0.02600            0.10282
# zestimateHighPercent                         -0.00719            0.11471
# restimateLowPercent                          -0.07204            0.01335
# restimateHighPercent                         -0.16275            0.09191
# taxAssessedValue                              0.09084            0.02309
# propertyTaxRate                              -0.19459            0.46351
# resoFacts_hoaFee                              0.02768            0.07703
# resoFacts_pricePerSquareFoot                  0.11744           -0.14756
# solarPotential_sunScore                       0.02920            0.09393
# bedrooms                                      0.14923            0.00682
# bathrooms                                     0.12261            0.10485
# resoFacts_hasFireplace                        1.00000           -0.01040
# resoFacts_parking                            -0.01040            1.00000
# resoFacts_daysOnZillow                        0.01964           -0.02989
# resoFacts_hasAttachedProperty                -0.05793            0.11955
# resoFacts_hasGarage                           0.02686            0.72494
# resoFacts_hasPetsAllowed                     -0.06272            0.08920
# resoFacts_hasSpa                              0.16601           -0.04453
# resoFacts_hasView                             0.08878            0.17535
# resoFacts_yearBuilt                           0.05731           -0.02319
# Elementary_Distance                          -0.04176           -0.09128
# Elementary_Ratings                            0.22118           -0.07332
# Middle_Distance                               0.04197           -0.04435
# Middle_Ratings                                0.21823           -0.22605
# High_Distance                                 0.03515            0.01946
# High_Ratings                                  0.24070           -0.18084
# desc_sentiment                                0.01435           -0.01653
#
#                                resoFacts_daysOnZillow  \
# index                                         0.15198
# lotAreaValue                                  0.00984
# zestimate                                     0.05488
# rentZestimate                                 0.00909
# livingAreaValue                              -0.01365
# lastSoldPrice                                 0.07189
# zestimateLowPercent                          -0.04140
# zestimateHighPercent                         -0.05103
# restimateLowPercent                          -0.02438
# restimateHighPercent                         -0.02904
# taxAssessedValue                              0.09023
# propertyTaxRate                              -0.00292
# resoFacts_hoaFee                              0.00101
# resoFacts_pricePerSquareFoot                  0.09359
# solarPotential_sunScore                      -0.00639
# bedrooms                                      0.00806
# bathrooms                                     0.00799
# resoFacts_hasFireplace                        0.01964
# resoFacts_parking                            -0.02989
# resoFacts_daysOnZillow                        1.00000
# resoFacts_hasAttachedProperty                -0.00593
# resoFacts_hasGarage                          -0.01705
# resoFacts_hasPetsAllowed                     -0.00486
# resoFacts_hasSpa                             -0.01055
# resoFacts_hasView                            -0.03603
# resoFacts_yearBuilt                           0.00887
# Elementary_Distance                           0.00301
# Elementary_Ratings                            0.01803
# Middle_Distance                               0.00007
# Middle_Ratings                                0.01988
# High_Distance                                 0.03231
# High_Ratings                                  0.02612
# desc_sentiment                               -0.04802
#
#                                resoFacts_hasAttachedProperty  \
# index                                                0.01802
# lotAreaValue                                        -0.15409
# zestimate                                           -0.08200
# rentZestimate                                       -0.03051
# livingAreaValue                                     -0.05157
# lastSoldPrice                                       -0.06022
# zestimateLowPercent                                 -0.07675
# zestimateHighPercent                                -0.07635
# restimateLowPercent                                  0.05390
# restimateHighPercent                                 0.00908
# taxAssessedValue                                     0.01587
# propertyTaxRate                                      0.06176
# resoFacts_hoaFee                                     0.09787
# resoFacts_pricePerSquareFoot                        -0.02423
# solarPotential_sunScore                              0.04455
# bedrooms                                            -0.09087
# bathrooms                                           -0.01037
# resoFacts_hasFireplace                              -0.05793
# resoFacts_parking                                    0.11955
# resoFacts_daysOnZillow                              -0.00593
# resoFacts_hasAttachedProperty                        1.00000
# resoFacts_hasGarage                                  0.11296
# resoFacts_hasPetsAllowed                             0.25162
# resoFacts_hasSpa                                    -0.03772
# resoFacts_hasView                                    0.03436
# resoFacts_yearBuilt                                 -0.37023
# Elementary_Distance                                 -0.00992
# Elementary_Ratings                                  -0.01483
# Middle_Distance                                      0.01489
# Middle_Ratings                                      -0.04582
# High_Distance                                        0.01040
# High_Ratings                                        -0.01010
# desc_sentiment                                      -0.01142
#
#                                resoFacts_hasGarage  resoFacts_hasPetsAllowed  \
# index                                      0.38172                   0.15006
# lotAreaValue                              -0.02693                  -0.16584
# zestimate                                 -0.05185                  -0.17733
# rentZestimate                              0.07213                  -0.13435
# livingAreaValue                            0.08407                  -0.09191
# lastSoldPrice                              0.01616                  -0.13193
# zestimateLowPercent                        0.13798                   0.02747
# zestimateHighPercent                       0.14050                   0.02088
# restimateLowPercent                        0.02485                   0.05409
# restimateHighPercent                       0.06774                   0.06987
# taxAssessedValue                           0.00458                  -0.06730
# propertyTaxRate                            0.51708                   0.24365
# resoFacts_hoaFee                           0.08211                   0.15421
# resoFacts_pricePerSquareFoot              -0.14637                  -0.10929
# solarPotential_sunScore                    0.08121                   0.06988
# bedrooms                                   0.02943                  -0.15079
# bathrooms                                  0.11161                  -0.06313
# resoFacts_hasFireplace                     0.02686                  -0.06272
# resoFacts_parking                          0.72494                   0.08920
# resoFacts_daysOnZillow                    -0.01705                  -0.00486
# resoFacts_hasAttachedProperty              0.11296                   0.25162
# resoFacts_hasGarage                        1.00000                   0.13846
# resoFacts_hasPetsAllowed                   0.13846                   1.00000
# resoFacts_hasSpa                          -0.07705                  -0.08635
# resoFacts_hasView                          0.08817                   0.23656
# resoFacts_yearBuilt                       -0.02377                  -0.09354
# Elementary_Distance                       -0.10045                   0.03639
# Elementary_Ratings                        -0.08734                  -0.09154
# Middle_Distance                           -0.04341                  -0.00190
# Middle_Ratings                            -0.22173                  -0.13971
# High_Distance                              0.01560                  -0.03939
# High_Ratings                              -0.21088                  -0.12197
# desc_sentiment                            -0.04048                  -0.01958
#
#                                resoFacts_hasSpa  resoFacts_hasView  \
# index                                  -0.13728           -0.06599
# lotAreaValue                           -0.00065            0.01008
# zestimate                               0.10638            0.12234
# rentZestimate                           0.10743            0.14817
# livingAreaValue                         0.06401            0.07204
# lastSoldPrice                          -0.01884            0.11179
# zestimateLowPercent                    -0.06322            0.00108
# zestimateHighPercent                   -0.07095            0.02100
# restimateLowPercent                     0.00635            0.07405
# restimateHighPercent                   -0.04844           -0.02543
# taxAssessedValue                        0.05057            0.14134
# propertyTaxRate                        -0.19052            0.01645
# resoFacts_hoaFee                        0.01956            0.03095
# resoFacts_pricePerSquareFoot           -0.00174            0.01003
# solarPotential_sunScore                 0.00710            0.01897
# bedrooms                                0.03671            0.03694
# bathrooms                               0.10442            0.07393
# resoFacts_hasFireplace                  0.16601            0.08878
# resoFacts_parking                      -0.04453            0.17535
# resoFacts_daysOnZillow                 -0.01055           -0.03603
# resoFacts_hasAttachedProperty          -0.03772            0.03436
# resoFacts_hasGarage                    -0.07705            0.08817
# resoFacts_hasPetsAllowed               -0.08635            0.23656
# resoFacts_hasSpa                        1.00000            0.09297
# resoFacts_hasView                       0.09297            1.00000
# resoFacts_yearBuilt                     0.04467            0.00149
# Elementary_Distance                    -0.01942            0.03479
# Elementary_Ratings                      0.13768            0.10731
# Middle_Distance                         0.01511           -0.00091
# Middle_Ratings                          0.11145            0.02703
# High_Distance                           0.01547            0.07398
# High_Ratings                            0.15376            0.05100
# desc_sentiment                          0.00157           -0.03592
#
#                                resoFacts_yearBuilt  Elementary_Distance  \
# index                                     -0.01326             -0.17892
# lotAreaValue                               0.02352             -0.11464
# zestimate                                  0.08211              0.01973
# rentZestimate                              0.06761             -0.02634
# livingAreaValue                            0.10245             -0.02906
# lastSoldPrice                              0.07776              0.04842
# zestimateLowPercent                       -0.06393             -0.07635
# zestimateHighPercent                      -0.08341             -0.08349
# restimateLowPercent                       -0.04098             -0.01130
# restimateHighPercent                      -0.09494             -0.02233
# taxAssessedValue                           0.02776              0.08329
# propertyTaxRate                           -0.09241             -0.22192
# resoFacts_hoaFee                           0.01604             -0.00907
# resoFacts_pricePerSquareFoot              -0.00121              0.01499
# solarPotential_sunScore                    0.06252             -0.01111
# bedrooms                                   0.02912             -0.11862
# bathrooms                                  0.04917             -0.02765
# resoFacts_hasFireplace                     0.05731             -0.04176
# resoFacts_parking                         -0.02319             -0.09128
# resoFacts_daysOnZillow                     0.00887              0.00301
# resoFacts_hasAttachedProperty             -0.37023             -0.00992
# resoFacts_hasGarage                       -0.02377             -0.10045
# resoFacts_hasPetsAllowed                  -0.09354              0.03639
# resoFacts_hasSpa                           0.04467             -0.01942
# resoFacts_hasView                          0.00149              0.03479
# resoFacts_yearBuilt                        1.00000              0.02715
# Elementary_Distance                        0.02715              1.00000
# Elementary_Ratings                         0.04595              0.14136
# Middle_Distance                           -0.01102              0.03337
# Middle_Ratings                             0.04449             -0.04188
# High_Distance                              0.05463              0.08540
# High_Ratings                               0.06450              0.09635
# desc_sentiment                             0.01513             -0.05229
#
#                                Elementary_Ratings  Middle_Distance  \
# index                                    -0.29558         -0.01661
# lotAreaValue                              0.10353         -0.01933
# zestimate                                 0.35018          0.04240
# rentZestimate                             0.27160          0.01127
# livingAreaValue                           0.11201          0.00658
# lastSoldPrice                             0.16031          0.04033
# zestimateLowPercent                      -0.12080         -0.07690
# zestimateHighPercent                     -0.07910         -0.09498
# restimateLowPercent                       0.01605          0.00561
# restimateHighPercent                     -0.06694         -0.01824
# taxAssessedValue                          0.17767          0.03428
# propertyTaxRate                          -0.38394         -0.13102
# resoFacts_hoaFee                          0.01566         -0.01745
# resoFacts_pricePerSquareFoot              0.20334          0.03377
# solarPotential_sunScore                   0.00042         -0.00912
# bedrooms                                  0.01938          0.00901
# bathrooms                                 0.10741          0.01288
# resoFacts_hasFireplace                    0.22118          0.04197
# resoFacts_parking                        -0.07332         -0.04435
# resoFacts_daysOnZillow                    0.01803          0.00007
# resoFacts_hasAttachedProperty            -0.01483          0.01489
# resoFacts_hasGarage                      -0.08734         -0.04341
# resoFacts_hasPetsAllowed                 -0.09154         -0.00190
# resoFacts_hasSpa                          0.13768          0.01511
# resoFacts_hasView                         0.10731         -0.00091
# resoFacts_yearBuilt                       0.04595         -0.01102
# Elementary_Distance                       0.14136          0.03337
# Elementary_Ratings                        1.00000          0.00259
# Middle_Distance                           0.00259          1.00000
# Middle_Ratings                            0.44053          0.06275
# High_Distance                             0.08427          0.10927
# High_Ratings                              0.42341          0.07237
# desc_sentiment                            0.08217         -0.00230
#
#                                Middle_Ratings  High_Distance  High_Ratings  \
# index                                -0.35118        0.00025      -0.32074
# lotAreaValue                          0.15924        0.04215       0.14232
# zestimate                             0.33472        0.07586       0.36674
# rentZestimate                         0.22306        0.07682       0.22170
# livingAreaValue                       0.09481        0.09763       0.14976
# lastSoldPrice                         0.13060        0.11260       0.16161
# zestimateLowPercent                  -0.10078       -0.04210      -0.10004
# zestimateHighPercent                 -0.08855       -0.02877      -0.10134
# restimateLowPercent                  -0.03010        0.00677      -0.01194
# restimateHighPercent                 -0.13858        0.04170      -0.06189
# taxAssessedValue                      0.10995        0.10581       0.13467
# propertyTaxRate                      -0.45131       -0.06239      -0.47364
# resoFacts_hoaFee                     -0.10960       -0.15992      -0.13740
# resoFacts_pricePerSquareFoot          0.22537       -0.02181       0.21590
# solarPotential_sunScore              -0.00466        0.02883      -0.01237
# bedrooms                              0.12712        0.06917       0.15454
# bathrooms                             0.08284        0.06827       0.10687
# resoFacts_hasFireplace                0.21823        0.03515       0.24070
# resoFacts_parking                    -0.22605        0.01946      -0.18084
# resoFacts_daysOnZillow                0.01988        0.03231       0.02612
# resoFacts_hasAttachedProperty        -0.04582        0.01040      -0.01010
# resoFacts_hasGarage                  -0.22173        0.01560      -0.21088
# resoFacts_hasPetsAllowed             -0.13971       -0.03939      -0.12197
# resoFacts_hasSpa                      0.11145        0.01547       0.15376
# resoFacts_hasView                     0.02703        0.07398       0.05100
# resoFacts_yearBuilt                   0.04449        0.05463       0.06450
# Elementary_Distance                  -0.04188        0.08540       0.09635
# Elementary_Ratings                    0.44053        0.08427       0.42341
# Middle_Distance                       0.06275        0.10927       0.07237
# Middle_Ratings                        1.00000        0.04078       0.46051
# High_Distance                         0.04078        1.00000       0.24208
# High_Ratings                          0.46051        0.24208       1.00000
# desc_sentiment                        0.04635        0.05137       0.06691
#
#                                desc_sentiment
# index                                 0.02371
# lotAreaValue                          0.02916
# zestimate                            -0.01218
# rentZestimate                         0.00322
# livingAreaValue                      -0.05240
# lastSoldPrice                        -0.01013
# zestimateLowPercent                  -0.05189
# zestimateHighPercent                 -0.02219
# restimateLowPercent                  -0.03481
# restimateHighPercent                  0.03555
# taxAssessedValue                      0.00151
# propertyTaxRate                       0.02604
# resoFacts_hoaFee                      0.03419
# resoFacts_pricePerSquareFoot         -0.04167
# solarPotential_sunScore               0.05789
# bedrooms                             -0.01873
# bathrooms                            -0.01836
# resoFacts_hasFireplace                0.01435
# resoFacts_parking                    -0.01653
# resoFacts_daysOnZillow               -0.04802
# resoFacts_hasAttachedProperty        -0.01142
# resoFacts_hasGarage                  -0.04048
# resoFacts_hasPetsAllowed             -0.01958
# resoFacts_hasSpa                      0.00157
# resoFacts_hasView                    -0.03592
# resoFacts_yearBuilt                   0.01513
# Elementary_Distance                  -0.05229
# Elementary_Ratings                    0.08217
# Middle_Distance                      -0.00230
# Middle_Ratings                        0.04635
# High_Distance                         0.05137
# High_Ratings                          0.06691
# desc_sentiment                        1.00000

# %% [markdown]
# # Train-Test Split

# %%
y = df.zestimate

# %%
x= df.drop('zestimate', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2, random_state=123)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (542, 37)
# (542,)
# (136, 37)
# (136,)

# %% [markdown]
# # One Hot Encoding

# %%
df_cat.columns
# Out:
# Index(['city', 'county', 'description', 'parentRegion_name', 'dateSoldString',
#        'resoFacts_flooring', 'schools'],
#       dtype='object')

# %%
cat_columns=['city', 'county']

# %%
from scipy.sparse import coo_matrix

X_train_cat_processed = coo_matrix((542, 0))
X_test_cat_processed = coo_matrix((136, 0))

# %%
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import hstack

from sklearn import preprocessing
vectorizer= preprocessing.OneHotEncoder(handle_unknown = 'ignore')
for x in cat_columns:
    
    
# 1. INSTANTIATE
    
    

        
    one_hot_train = vectorizer.fit_transform(X_train[x].values.reshape(-1,1))
    one_hot_test = vectorizer.transform(X_test[x].values.reshape(-1,1))
    vectorizer.get_feature_names()
    
    X_train_cat_processed= hstack((X_train_cat_processed,one_hot_train)).tocsr()
    X_test_cat_processed= hstack((X_test_cat_processed,one_hot_test)).tocsr()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(X_train_cat_processed.shape)
print(X_test_cat_processed.shape)
# Out:
# (542, 7)
# (136, 7)

# %% [markdown]
# # Numeric Data Preparation

# %%
from scipy.sparse import coo_matrix

X_train_num_processed = coo_matrix((542,0))
X_test_num_processed = coo_matrix((136,0))

# %%
num_cols= [ 'bedrooms','rentZestimate','lastSoldPrice','resoFacts_hasFireplace','Elementary_Ratings','Elementary_Distance',
        'Middle_Ratings', 'High_Ratings','High_Distance' ]

# %%
for x in num_cols:
    

    s_train = (X_train[x].values.reshape(-1, 1))

    s_test = (X_test[x].values.reshape(-1, 1))

    
    X_train_num_processed= hstack((X_train_num_processed,s_train)).tocsr()
    X_test_num_processed= hstack((X_test_num_processed,s_test)).tocsr()

# %%
print(X_train_num_processed.shape)
print(X_test_num_processed.shape)
# Out:
# (542, 9)
# (136, 9)

# %% [markdown]
# # Linear Regression

# %%
from scipy.sparse import hstack
X_train_processed = hstack((X_train_cat_processed,X_train_num_processed )).tocsr()
X_test_processed = hstack(( X_test_cat_processed,X_test_num_processed)).tocsr()
print(X_test_processed.shape)
print(X_train_processed.shape)
# Out:
# (136, 16)
# (542, 16)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train_processed, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = regressor.predict(X_test_processed)

# %%
df_out = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df_out
# Out:
#            Actual     Predicted
# 290 1424221.00000 1614998.24150
# 226 1140500.00000 1303641.72916
# 415 1599900.00000 1645092.24809
# 707  478700.00000  580470.77229
# 441 3749700.00000 2804328.21282
# 744 1006950.00000  526350.78423
# 469 1974600.00000 1588395.74495
# 383  417400.00000  562383.34410
# 117 1465255.00000 1149477.31230
# 472  756100.00000  906660.59689
# 364  954600.00000  775629.86742
# 804  955000.00000  999682.31844
# 319  836500.00000  612761.16796
# 171  522500.00000  606853.55354
# 679 1336700.00000 1285697.75513
# 136 1162200.00000 1416171.77664
# 72   552960.00000  916193.51914
# 538  814900.00000  679957.57637
# 12   504523.00000  778839.35552
# 353  713000.00000  812496.48852
# 321  867106.00000  732766.54045
# 712  934000.00000 1279930.22413
# 525 1447900.00000 1600466.46409
# 378  772400.00000  957101.21271
# 618 1173500.00000  807615.58531
# 107 1316549.00000 1516005.81406
# 818  497500.00000 1150050.93982
# 156 1110791.00000  760260.03555
# 798 1018900.00000  975218.24855
# 370 1060600.00000 1390305.09753
# 654  976356.00000  724110.58743
# 365  983900.00000  575001.97977
# 534 1610600.00000 1602340.36343
# 697  386050.00000  403122.88577
# 471  716550.00000  897141.33416
# 814  719800.00000  551979.42188
# 550  859900.00000  898813.50952
# 328 1440400.00000 1398130.10015
# 196 1160629.00000  902668.97582
# 54   944100.00000 1108205.46956
# 17  1517288.00000 1136450.62023
# 102 2019893.00000 1500791.67202
# 101 2000841.00000 1764435.37709
# 192 1422098.00000 1362415.04356
# 214 1136900.00000 1110022.79162
# 579  800200.00000  759256.69142
# 218  840336.00000 1083211.52043
# 242 1374443.00000 1324968.96266
# 60  1110800.00000 1130058.28215
# 617  720300.00000  657045.73476
# 252  760003.00000  786541.23581
# 716 1707275.00000 1458069.56972
# 690 1870000.00000 1646846.49663
# 206  802069.00000 1075394.03480
# 62  1203200.00000 1174814.01280
# 468  522500.00000  664662.91427
# 368 1376800.00000  959095.38587
# 352 1996300.00000 1648248.58940
# 437  735100.00000  562679.55710
# 269  600139.00000  854962.25006
# 729  902100.00000  920572.16687
# 685  714000.00000  866752.51642
# 400 1047550.00000  970301.02751
# 477  850500.00000  568957.01710
# 377  863500.00000 1084338.08852
# 223  251100.00000  491008.14892
# 337  638100.00000  764383.62958
# 489  701750.00000  838453.77719
# 10  1132000.00000 1390057.68568
# 224  691605.00000  734005.68409
# 260 1187400.00000 1302653.40248
# 172  886246.00000 1163156.15533
# 293 1540886.00000 1502304.33969
# 367  577700.00000  823046.75905
# 438  888500.00000  736126.58765
# 536  588950.00000  665839.07468
# 447 1532700.00000 1082605.91922
# 545  511000.00000  603121.75152
# 381 1589900.00000 1203304.52057
# 201 1127825.00000 1374693.10306
# 698 1000500.00000  675050.88207
# 302 2189673.00000 1786991.54941
# 763  822000.00000  725848.22990
# 526  735300.00000  624464.50432
# 231 1291147.00000 1335450.74208
# 235 1149971.00000 1504604.18797
# 650  672100.00000  747530.35775
# 420  744700.00000  501114.34993
# 110 1311400.00000 1194138.16544
# 530 1266300.00000 1310401.34370
# 69  1265200.00000 1446554.15279
# 409  545150.00000  894923.04383
# 75   948500.00000 1056221.60538
# 312  603000.00000  576298.08659
# 542  739100.00000  834961.82901
# 528  590300.00000  597417.56932
# 450  648300.00000  943108.89416
# 399  775800.00000 1050514.07284
# 673  372300.00000  506717.17581
# 719  836750.00000  758813.70560
# 258 1795383.00000 1674803.52778
# 5   1244480.00000 1581970.46648
# 695  334300.00000  458655.65148
# 331  807350.00000 1371754.11643
# 747  530000.00000  540159.25410
# 779  889400.00000 1114476.32703
# 608  755500.00000  876189.64044
# 251 1172098.00000 1109947.49986
# 424  669550.00000  954560.53055
# 766  958500.00000  932863.18069
# 180  702644.00000  701707.92048
# 384  789556.00000  942849.90558
# 236  971158.00000 1237905.08168
# 342  802600.00000  490458.68518
# 289 1770061.00000 1625078.86735
# 174 1282300.00000 1354942.28818
# 805  761991.00000  792592.56697
# 44  1001000.00000  972027.27071
# 330  853300.00000  724154.68429
# 195  803558.00000 1106482.12947
# 39  1417379.00000 1001992.32935
# 301 1148766.00000 1053486.67565
# 387  667900.00000  659503.31151
# 655  868400.00000  951360.15486
# 391  589500.00000  746209.51210
# 475  637100.00000  778823.42347
# 678 1004000.00000 1308566.23915
# 379  950900.00000  701990.07089
# 247 1398969.00000 1505159.65113
# 279  666301.00000 1003049.46326
# 157 1042083.00000 1197761.87306
# 516  671500.00000  355530.05933
# 600  450400.00000  428261.80081
# 591  611100.00000  804274.59796
# 572 1225900.00000 1174433.14221
# 504  811500.00000  814073.31662

# %%
from sklearn.metrics import r2_score
r2_score =r2_score(Y_test, Y_pred)
rows , col =X_train_processed.shape
adj_R2 = 1- ((1-r2_score) * (rows-1)/(rows-col-1)) #Adj R2 = 1-(1-R2)*(n-1)/(n-p-1)
print('R2 is:', r2_score.round(4))
print('Adjusted R2 is:', adj_R2.round(3))
# Out:
# R2 is: 0.7247
# Adjusted R2 is: 0.716

# %% [markdown]
# # OLS regresssion

# %%
X_train_test_processed=pd.concat([pd.DataFrame(X_train_processed.todense()),pd.DataFrame(X_test_processed.todense())],ignore_index=True)
Y_train_test_processed = pd.concat([pd.DataFrame(Y_train),pd.DataFrame(Y_test)], ignore_index=True)

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats


X2 = sm.add_constant(X_train_test_processed)
est = sm.OLS(Y_train_test_processed, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              zestimate   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     106.9
# Date:                Mon, 04 Apr 2022   Prob (F-statistic):          5.15e-153
# Time:                        13:24:05   Log-Likelihood:                -9449.5
# No. Observations:                 678   AIC:                         1.893e+04
# Df Residuals:                     664   BIC:                         1.899e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.576e+05    4.4e+04     -5.852      0.000   -3.44e+05   -1.71e+05
# 0          -4.151e+04   7.65e+04     -0.543      0.588   -1.92e+05    1.09e+05
# 1           3.373e+04   7.56e+04      0.446      0.656   -1.15e+05    1.82e+05
# 2          -2.186e+05   1.67e+05     -1.306      0.192   -5.47e+05     1.1e+05
# 3          -3.553e+04   2.36e+04     -1.505      0.133   -8.19e+04    1.08e+04
# 4           4298.6265   2.22e+05      0.019      0.985   -4.31e+05     4.4e+05
# 5          -2.221e+05   4.72e+04     -4.701      0.000   -3.15e+05   -1.29e+05
# 6          -3.553e+04   2.36e+04     -1.505      0.133   -8.19e+04    1.08e+04
# 7           5.898e+04   9965.453      5.919      0.000    3.94e+04    7.85e+04
# 8            273.3929     14.823     18.444      0.000     244.287     302.498
# 9              0.1687      0.034      4.898      0.000       0.101       0.236
# 10          9328.0295    2.4e+04      0.388      0.698   -3.79e+04    5.65e+04
# 11           1.59e+04   6535.853      2.433      0.015    3070.340    2.87e+04
# 12         -1876.9669   3.58e+04     -0.052      0.958   -7.22e+04    6.85e+04
# 13          1.023e+04   8658.821      1.181      0.238   -6776.381    2.72e+04
# 14          2.679e+04   7743.199      3.459      0.001    1.16e+04     4.2e+04
# 15         -2.148e+04   2.14e+04     -1.002      0.317   -6.36e+04    2.06e+04
# ==============================================================================
# Omnibus:                      514.110   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24060.259
# Skew:                           2.879   Prob(JB):                         0.00
# Kurtosis:                      31.610   Cond. No.                     8.66e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.17e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
 # [starts from 7 'bedrooms','rentZestimate','lastSoldPrice','resoFacts_hasFireplace','Elementary_Ratings','Elementary_Distance',
  #      'Middle_Ratings', 'High_Ratings','High_Distance' ]
